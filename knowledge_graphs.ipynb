# %%
import os
import pandas as pd
import numpy as np
import zipfile

# %%
data_path = f"Data"
raw_data = os.path.join(data_path, f"Raw Data")
preprocess_path = os.path.join(data_path, f"Preprocessed Data")
analysis_path = os.path.join(data_path, f"Analysis Data") 
results_path = f"Results"

# %% [markdown]
# # Q1 Knowledge Graph

# %%
aqi_data = pd.read_csv(os.path.join(preprocess_path, "aqi_data.csv"))

# %%
aqi_data
# Out:
#       FIPS         State    County  State Code  County Code  Year  RUCC  \
# 0     6021    California     Glenn           6           21  2018   6.0
# 1     6023    California  Humboldt           6           23  2018   5.0
# 2     6025    California  Imperial           6           25  2018   3.0
# 3     6029    California      Kern           6           29  2018   2.0
# 4     6033    California      Lake           6           33  2018   4.0
# ..     ...           ...       ...         ...          ...   ...   ...
# 128  42111  Pennsylvania  Somerset          42          111  2023   6.0
# 129  42117  Pennsylvania     Tioga          42          117  2023   8.0
# 130  48113         Texas    Dallas          48          113  2023   1.0
# 131  48221         Texas      Hood          48          221  2023   4.0
# 132  48323         Texas  Maverick          48          323  2023   3.0
#
#      Population  Max AQI  90th Percentile AQI  Median AQI
# 0         27899      230                   69          36
# 1        136502      163                   53          34
# 2        181062      286                  108          62
# 3        893618      190                  142          84
# 4         64394      208                   43          33
# ..          ...      ...                  ...         ...
# 128       72197       93                   58          41
# 129       40840      100                   74          44
# 130     2606358      172                   74          47
# 131       67774      105                   58          38
# 132       57762      101                   62          28
#
# [133 rows x 11 columns]

# %%
''' Subject: <County_Year> 
Predictes and Objects: 
1. hasState: State name
2. hasRUCC: RUCC
3. hasPopulation: Population Estimate
4. hasMaxAQI: Max AQI
 '''
from rdflib import Graph, Literal, RDF, URIRef, Namespace

EX = Namespace("http://example.org/ke#")
g = Graph()

for index, row in aqi_data.iterrows():
    county_year = EX[f"{row['County'].replace(' ', '_')}_{row['Year']}"]
    state = EX[f"State#{row['State'].replace(' ', '_')}"]
    county = EX[f"County#{row['County'].replace(' ', '_')}"]
    
    rucc = EX[f"RUCC#{row['RUCC']}"]
    population = EX[f"Population#{row['Population']}"]
    aqi = EX[f"MaxAQI#{row['Max AQI']}"]

    g.add((state, EX.hasState, county))
    g.add((county, EX.hasRUCC, rucc))
    g.add((county_year, EX.hasCounty, county))
    g.add((county_year, EX.hasPopulation, population))
    g.add((county_year, EX.hasMedianAQI, aqi))

# Serialize the RDF graph to Turtle format
# print(g.serialize(format='turtle'))

# %%
from pyvis.network import Network
net = Network(height='750px', 
              width='100%', 
              directed=False, 
              neighborhood_highlight=True)

# Add nodes and edges to the network
for subject, predicate, object in g:
    subject_label = str(subject).split("#")[-1]
    predicate_label = str(predicate).split("#")[-1]
    object_label = str(object).split("#")[-1]

    subject_type = str(subject).split("#")[-2]
    predicate_type = str(predicate).split("#")[-2]
    object_type = str(object).split("#")[-2]

    
        
    if subject_label not in net.node_ids:
        if "ke" in subject_type:
            subject_title = subject_label
        else:
            subject_title = subject_type + ": " + subject_label
            
        net.add_node(subject_label, 
                     label=subject_label, 
                     title=subject_title, 
                     labelHighlightBold=True)
        
    if object_label not in net.node_ids:
        if "ke" in object_type:
            object_title = object_label
        else:
            object_title = object_type + ": " + object_label
            
        net.add_node(object_label, 
                     label=object_label, 
                     title=object_title, 
                     labelHighlightBold=True)

    edge_color = {
        'hasState': 'red',
        'hasCounty': 'orange',
        'hasPopulation': 'green',
        'hasMedianAQI': 'blue',
        'hasRUCC': 'black'
    }.get(predicate_label, 'grey')

    
    net.add_edge(subject_label, 
                     object_label, 
                     title=predicate_label, 
                     label=predicate_label, 
                     color=edge_color)
    
# # Show the network
net.save_graph(os.path.join(results_path, "Q1.html"))
net.show("Q1.html", local=False, notebook=False)
# Out:
# Q1.html

# %% [markdown]
# # Q3 Knowledge Graph

# %%
mobility_data = pd.read_csv(os.path.join(preprocess_path, "merged_pop_mobility.csv"))

# %%
''' Subject: <County_URI> 
Predictes and Objects: 
1. hasState: State name
2. hasRUCC: RUCC
3. hasPopulation: Population Estimate
4. hasMaxAQI: Max AQI
5. hasVMT: Vehicle Miles Traveled
 '''
from rdflib import Graph, Literal, RDF, URIRef, Namespace

EX = Namespace("http://example.org/ke#")
g = Graph()

for index, row in mobility_data.iterrows():
    county_year = EX[f"{row['County'].replace(' ', '_')}_{row['Year']}"]
    state = EX[f"State#{row['State'].replace(' ', '_')}"]
    county = EX[f"County#{row['County'].replace(' ', '_')}"]
    
    rucc = EX[f"RUCC#{row['RUCC']}"]
    population = EX[f"Population#{row['Population']}"]
    aqi = EX[f"MaxAQI#{row['Max AQI']}"]

    vmt = EX[f"VMT#{row['vmt']}"]

    g.add((county, EX.hasState, state))
    g.add((county, EX.hasRUCC, rucc))
    g.add((county_year, EX.hasCounty, county))
    g.add((county_year, EX.hasPopulation, population))
    g.add((county_year, EX.hasMaxAQI, aqi))
    g.add((county_year, EX.hasVMT, vmt))

# Serialize the RDF graph to Turtle format
print(g.serialize(format='turtle'))
# Out:
# @prefix ns1: <http://example.org/ke#> .
#
# ns1:Dallas_2018 ns1:hasCounty <http://example.org/ke#County#Dallas> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#161> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2629764> ;
#     ns1:hasVMT <http://example.org/ke#VMT#11826623292.0> .
#
# ns1:Dallas_2019 ns1:hasCounty <http://example.org/ke#County#Dallas> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#143> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2635603> ;
#     ns1:hasVMT <http://example.org/ke#VMT#11523452066.0> .
#
# ns1:Dallas_2020 ns1:hasCounty <http://example.org/ke#County#Dallas> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#135> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2610112> ;
#     ns1:hasVMT <http://example.org/ke#VMT#10764144411.0> .
#
# ns1:Hood_2018 ns1:hasCounty <http://example.org/ke#County#Hood> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#133> ;
#     ns1:hasPopulation <http://example.org/ke#Population#60249> ;
#     ns1:hasVMT <http://example.org/ke#VMT#181061841.6> .
#
# ns1:Hood_2019 ns1:hasCounty <http://example.org/ke#County#Hood> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#133> ;
#     ns1:hasPopulation <http://example.org/ke#Population#61762> ;
#     ns1:hasVMT <http://example.org/ke#VMT#183377087.7> .
#
# ns1:Hood_2020 ns1:hasCounty <http://example.org/ke#County#Hood> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#100> ;
#     ns1:hasPopulation <http://example.org/ke#Population#62057> ;
#     ns1:hasVMT <http://example.org/ke#VMT#176512942.8> .
#
# ns1:Maverick_2018 ns1:hasCounty <http://example.org/ke#County#Maverick> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#100> ;
#     ns1:hasPopulation <http://example.org/ke#Population#57970> ;
#     ns1:hasVMT <http://example.org/ke#VMT#255302783.2> .
#
# ns1:Maverick_2019 ns1:hasCounty <http://example.org/ke#County#Maverick> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#104> ;
#     ns1:hasPopulation <http://example.org/ke#Population#58357> ;
#     ns1:hasVMT <http://example.org/ke#VMT#259485519.0> .
#
# ns1:Maverick_2020 ns1:hasCounty <http://example.org/ke#County#Maverick> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#160> ;
#     ns1:hasPopulation <http://example.org/ke#Population#57875> ;
#     ns1:hasVMT <http://example.org/ke#VMT#217110757.1> .
#
# ns1:Sarpy_2018 ns1:hasCounty <http://example.org/ke#County#Sarpy> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#93> ;
#     ns1:hasPopulation <http://example.org/ke#Population#184106> ;
#     ns1:hasVMT <http://example.org/ke#VMT#569887410.1> .
#
# ns1:Sarpy_2019 ns1:hasCounty <http://example.org/ke#County#Sarpy> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#80> ;
#     ns1:hasPopulation <http://example.org/ke#Population#186893> ;
#     ns1:hasVMT <http://example.org/ke#VMT#566793881.8> .
#
# ns1:Sarpy_2020 ns1:hasCounty <http://example.org/ke#County#Sarpy> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#149> ;
#     ns1:hasPopulation <http://example.org/ke#Population#191167> ;
#     ns1:hasVMT <http://example.org/ke#VMT#484488858.3> .
#
# ns1:Somerset_2018 ns1:hasCounty <http://example.org/ke#County#Somerset> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#90> ;
#     ns1:hasPopulation <http://example.org/ke#Population#73951> ;
#     ns1:hasVMT <http://example.org/ke#VMT#468740329.2> .
#
# ns1:Somerset_2019 ns1:hasCounty <http://example.org/ke#County#Somerset> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#80> ;
#     ns1:hasPopulation <http://example.org/ke#Population#73442> ;
#     ns1:hasVMT <http://example.org/ke#VMT#472759734.7> .
#
# ns1:Somerset_2020 ns1:hasCounty <http://example.org/ke#County#Somerset> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#71> ;
#     ns1:hasPopulation <http://example.org/ke#Population#74019> ;
#     ns1:hasVMT <http://example.org/ke#VMT#404374594.9> .
#
# ns1:Tioga_2018 ns1:hasCounty <http://example.org/ke#County#Tioga> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#97> ;
#     ns1:hasPopulation <http://example.org/ke#Population#40725> ;
#     ns1:hasVMT <http://example.org/ke#VMT#69919035.0> .
#
# ns1:Tioga_2019 ns1:hasCounty <http://example.org/ke#County#Tioga> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#74> ;
#     ns1:hasPopulation <http://example.org/ke#Population#40665> ;
#     ns1:hasVMT <http://example.org/ke#VMT#75665930.8> .
#
# ns1:Tioga_2020 ns1:hasCounty <http://example.org/ke#County#Tioga> ;
#     ns1:hasMaxAQI <http://example.org/ke#MaxAQI#79> ;
#     ns1:hasPopulation <http://example.org/ke#Population#41025> ;
#     ns1:hasVMT <http://example.org/ke#VMT#68625797.88> .
#
# <http://example.org/ke#County#Dallas> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> ;
#     ns1:hasState <http://example.org/ke#State#Texas> .
#
# <http://example.org/ke#County#Hood> ns1:hasRUCC <http://example.org/ke#RUCC#4.0> ;
#     ns1:hasState <http://example.org/ke#State#Texas> .
#
# <http://example.org/ke#County#Maverick> ns1:hasRUCC <http://example.org/ke#RUCC#3.0> ;
#     ns1:hasState <http://example.org/ke#State#Texas> .
#
# <http://example.org/ke#County#Sarpy> ns1:hasRUCC <http://example.org/ke#RUCC#2.0> ;
#     ns1:hasState <http://example.org/ke#State#Nebraska> .
#
# <http://example.org/ke#County#Somerset> ns1:hasRUCC <http://example.org/ke#RUCC#6.0> ;
#     ns1:hasState <http://example.org/ke#State#Pennsylvania> .
#
# <http://example.org/ke#County#Tioga> ns1:hasRUCC <http://example.org/ke#RUCC#8.0> ;
#     ns1:hasState <http://example.org/ke#State#Pennsylvania> .

# %%
from pyvis.network import Network
net = Network(height='750px', width='100%', directed=True, neighborhood_highlight=True)

# Add nodes and edges to the network
for subject, predicate, object in g:
    subject_label = str(subject).split("#")[-1]
    predicate_label = str(predicate).split("#")[-1]
    object_label = str(object).split("#")[-1]

    subject_type = str(subject).split("#")[-2]
    predicate_type = str(predicate).split("#")[-2]
    object_type = str(object).split("#")[-2]

    
        
    if subject_label not in net.node_ids:
        if "ke" in subject_type:
            subject_title = subject_label
        else:
            subject_title = subject_type + ": " + subject_label
        net.add_node(subject_label, 
                     label=subject_label, 
                     title=subject_title, 
                     labelHighlightBold=True)
        
    if object_label not in net.node_ids:
        if "ke" in object_type:
            object_title = object_label
        else:
            object_title = object_type + ": " + object_label
            
        net.add_node(object_label, 
                     label=object_label, 
                     title=object_title, 
                     labelHighlightBold=True)

    edge_color = {
        'hasState': 'red',
        'hasCounty': 'orange',
        'hasPopulation': 'green',
        'hasMaxAQI': 'blue',
        'hasRUCC': 'black',
        'hasVMT': 'pink',
    }.get(predicate_label, 'grey')

    
    net.add_edge(subject_label, 
                     object_label, 
                     title=predicate_label, 
                     label=predicate_label, 
                     color=edge_color)
    
# # Show the network
net.save_graph(os.path.join(results_path, "Q3.html"))
net.show("Q3.html", local=False, notebook=False)
# Out:
# Q3.html

# %% [markdown]
# # Q2 Knowledge Graph

# %%
pollutant_data = pd.read_csv(os.path.join(preprocess_path, "pollutant_population_aqi.csv"))

# %%
pollutant_data.head()
# Out:
#    Year       State        County  County Code  State Code  RUCC  FIPS  \
# 0  2018  California       Alameda            1           6   1.0  6001
# 1  2018  California         Butte            7           6   3.0  6007
# 2  2018  California  Contra Costa           13           6   1.0  6013
# 3  2018  California        Fresno           19           6   1.0  6019
# 4  2018  California      Humboldt           23           6   5.0  6023
#
#    Pollutant concentration (PPM) State Name Code     County Full Name  \
# 0                       0.616945              CA       Alameda County
# 1                       0.468219              CA         Butte County
# 2                       0.428311              CA  Contra Costa County
# 3                       0.379499              CA        Fresno County
# 4                       0.232778              CA      Humboldt County
#
#    Population Pollutant  Max AQI
# 0     1666596        CO    150.0
# 1      230330        CO    150.0
# 2     1150840        CO    150.0
# 3      991298        CO    150.0
# 4      136502        CO    150.0

# %%
''' Subject: <County_URI> 
Predictes and Objects: 
1. hasState: State name
2. hasRUCC: RUCC
3. hasPopulation: Population Estimate
4. hasMedianAQI: Median AQI
 '''
from rdflib import Graph, Literal, RDF, URIRef, Namespace

EX = Namespace("http://example.org/ke#")
g = Graph()

for index, row in pollutant_data.iterrows():
    county_year = EX[f"{row['County'].replace(' ', '_')}_{row['Year']}"]
    state = EX[f"State#{row['State'].replace(' ', '_')}"]
    county = EX[f"County#{row['County'].replace(' ', '_')}"]
    
    rucc = EX[f"RUCC#{row['RUCC']}"]
    aqi = EX[f"AQI#{row['Max AQI']}"]
    population = EX[f"Population#{row['Population']}"]
    pollutant_county = EX[f"Pollutant#{row['County'].replace(' ', '_')}_{row['Year']}_{row['Pollutant']}"]
    conc = EX[f"PollutantConcentration#{row['Pollutant concentration (PPM)']}"]
    
    g.add((state, EX.hasState, county))
    g.add((county, EX.hasRUCC, rucc))
    g.add((county_year, EX.hasCounty, county))
    g.add((county_year, EX.hasPopulation, population))
    g.add((county_year, EX.hasMaxAQI, aqi))
    g.add((county_year, EX.hasPollutant, pollutant_county))
    g.add((pollutant_county, EX.hasConcentration, conc))

print(g.serialize(format='turtle'))
# Out:
# @prefix ns1: <http://example.org/ke#> .
#
# ns1:Adams_2018 ns1:hasCounty <http://example.org/ke#County#Adams> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Adams_2018_CO>,
#         <http://example.org/ke#Pollutant#Adams_2018_NO2>,
#         <http://example.org/ke#Pollutant#Adams_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#103035> .
#
# ns1:Adams_2019 ns1:hasCounty <http://example.org/ke#County#Adams> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#85.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Adams_2019_CO>,
#         <http://example.org/ke#Pollutant#Adams_2019_NO2>,
#         <http://example.org/ke#Pollutant#Adams_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#102776> .
#
# ns1:Adams_2020 ns1:hasCounty <http://example.org/ke#County#Adams> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#86.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Adams_2020_CO>,
#         <http://example.org/ke#Pollutant#Adams_2020_NO2>,
#         <http://example.org/ke#Pollutant#Adams_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#103798> .
#
# ns1:Adams_2021 ns1:hasCounty <http://example.org/ke#County#Adams> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#129.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Adams_2021_CO>,
#         <http://example.org/ke#Pollutant#Adams_2021_NO2>,
#         <http://example.org/ke#Pollutant#Adams_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#105686> .
#
# ns1:Adams_2022 ns1:hasCounty <http://example.org/ke#County#Adams> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#97.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Adams_2022_CO>,
#         <http://example.org/ke#Pollutant#Adams_2022_NO2>,
#         <http://example.org/ke#Pollutant#Adams_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#105959> .
#
# ns1:Adams_2023 ns1:hasCounty <http://example.org/ke#County#Adams> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#216.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Adams_2023_CO>,
#         <http://example.org/ke#Pollutant#Adams_2023_NO2>,
#         <http://example.org/ke#Pollutant#Adams_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#106748> .
#
# ns1:Alameda_2018 ns1:hasCounty <http://example.org/ke#County#Alameda> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Alameda_2018_CO>,
#         <http://example.org/ke#Pollutant#Alameda_2018_NO2>,
#         <http://example.org/ke#Pollutant#Alameda_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1666596> .
#
# ns1:Alameda_2019 ns1:hasCounty <http://example.org/ke#County#Alameda> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Alameda_2019_CO>,
#         <http://example.org/ke#Pollutant#Alameda_2019_NO2>,
#         <http://example.org/ke#Pollutant#Alameda_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1668412> .
#
# ns1:Alameda_2020 ns1:hasCounty <http://example.org/ke#County#Alameda> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#218.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Alameda_2020_CO>,
#         <http://example.org/ke#Pollutant#Alameda_2020_NO2>,
#         <http://example.org/ke#Pollutant#Alameda_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1680466> .
#
# ns1:Alameda_2021 ns1:hasCounty <http://example.org/ke#County#Alameda> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#151.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Alameda_2021_CO>,
#         <http://example.org/ke#Pollutant#Alameda_2021_NO2>,
#         <http://example.org/ke#Pollutant#Alameda_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1644047> .
#
# ns1:Alameda_2022 ns1:hasCounty <http://example.org/ke#County#Alameda> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#122.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Alameda_2022_CO>,
#         <http://example.org/ke#Pollutant#Alameda_2022_NO2>,
#         <http://example.org/ke#Pollutant#Alameda_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1628259> .
#
# ns1:Alameda_2023 ns1:hasCounty <http://example.org/ke#County#Alameda> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#104.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Alameda_2023_CO>,
#         <http://example.org/ke#Pollutant#Alameda_2023_NO2>,
#         <http://example.org/ke#Pollutant#Alameda_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1622188> .
#
# ns1:Allegheny_2018 ns1:hasCounty <http://example.org/ke#County#Allegheny> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Allegheny_2018_CO>,
#         <http://example.org/ke#Pollutant#Allegheny_2018_NO2>,
#         <http://example.org/ke#Pollutant#Allegheny_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1217508> .
#
# ns1:Allegheny_2019 ns1:hasCounty <http://example.org/ke#County#Allegheny> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#161.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Allegheny_2019_CO>,
#         <http://example.org/ke#Pollutant#Allegheny_2019_NO2>,
#         <http://example.org/ke#Pollutant#Allegheny_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1215716> .
#
# ns1:Allegheny_2020 ns1:hasCounty <http://example.org/ke#County#Allegheny> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#128.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Allegheny_2020_CO>,
#         <http://example.org/ke#Pollutant#Allegheny_2020_NO2>,
#         <http://example.org/ke#Pollutant#Allegheny_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1249565> .
#
# ns1:Allegheny_2021 ns1:hasCounty <http://example.org/ke#County#Allegheny> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#153.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Allegheny_2021_CO>,
#         <http://example.org/ke#Pollutant#Allegheny_2021_NO2>,
#         <http://example.org/ke#Pollutant#Allegheny_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1245220> .
#
# ns1:Allegheny_2022 ns1:hasCounty <http://example.org/ke#County#Allegheny> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#151.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Allegheny_2022_CO>,
#         <http://example.org/ke#Pollutant#Allegheny_2022_NO2>,
#         <http://example.org/ke#Pollutant#Allegheny_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1232605> .
#
# ns1:Allegheny_2023 ns1:hasCounty <http://example.org/ke#County#Allegheny> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#212.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Allegheny_2023_CO>,
#         <http://example.org/ke#Pollutant#Allegheny_2023_NO2>,
#         <http://example.org/ke#Pollutant#Allegheny_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1224825> .
#
# ns1:Bexar_2018 ns1:hasCounty <http://example.org/ke#County#Bexar> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Bexar_2018_CO>,
#         <http://example.org/ke#Pollutant#Bexar_2018_NO2>,
#         <http://example.org/ke#Pollutant#Bexar_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1981061> .
#
# ns1:Bexar_2019 ns1:hasCounty <http://example.org/ke#County#Bexar> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#169.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Bexar_2019_CO>,
#         <http://example.org/ke#Pollutant#Bexar_2019_NO2>,
#         <http://example.org/ke#Pollutant#Bexar_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2002445> .
#
# ns1:Bexar_2020 ns1:hasCounty <http://example.org/ke#County#Bexar> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#158.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Bexar_2020_CO>,
#         <http://example.org/ke#Pollutant#Bexar_2020_NO2>,
#         <http://example.org/ke#Pollutant#Bexar_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2015501> .
#
# ns1:Bexar_2021 ns1:hasCounty <http://example.org/ke#County#Bexar> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#147.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Bexar_2021_CO>,
#         <http://example.org/ke#Pollutant#Bexar_2021_NO2>,
#         <http://example.org/ke#Pollutant#Bexar_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2030981> .
#
# ns1:Bexar_2022 ns1:hasCounty <http://example.org/ke#County#Bexar> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#194.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Bexar_2022_CO>,
#         <http://example.org/ke#Pollutant#Bexar_2022_NO2>,
#         <http://example.org/ke#Pollutant#Bexar_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2060191> .
#
# ns1:Bexar_2023 ns1:hasCounty <http://example.org/ke#County#Bexar> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#279.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Bexar_2023_CO>,
#         <http://example.org/ke#Pollutant#Bexar_2023_NO2>,
#         <http://example.org/ke#Pollutant#Bexar_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2087679> .
#
# ns1:Butte_2018 ns1:hasCounty <http://example.org/ke#County#Butte> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Butte_2018_CO>,
#         <http://example.org/ke#Pollutant#Butte_2018_NO2>,
#         <http://example.org/ke#Pollutant#Butte_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#230330> .
#
# ns1:Butte_2019 ns1:hasCounty <http://example.org/ke#County#Butte> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#173.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Butte_2019_CO>,
#         <http://example.org/ke#Pollutant#Butte_2019_NO2>,
#         <http://example.org/ke#Pollutant#Butte_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#218726> .
#
# ns1:Butte_2020 ns1:hasCounty <http://example.org/ke#County#Butte> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#379.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Butte_2020_CO>,
#         <http://example.org/ke#Pollutant#Butte_2020_NO2>,
#         <http://example.org/ke#Pollutant#Butte_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#210151> .
#
# ns1:Butte_2021 ns1:hasCounty <http://example.org/ke#County#Butte> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#233.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Butte_2021_CO>,
#         <http://example.org/ke#Pollutant#Butte_2021_NO2>,
#         <http://example.org/ke#Pollutant#Butte_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#206336> .
#
# ns1:Butte_2022 ns1:hasCounty <http://example.org/ke#County#Butte> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#119.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Butte_2022_CO>,
#         <http://example.org/ke#Pollutant#Butte_2022_NO2>,
#         <http://example.org/ke#Pollutant#Butte_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#207369> .
#
# ns1:Butte_2023 ns1:hasCounty <http://example.org/ke#County#Butte> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#87.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Butte_2023_CO>,
#         <http://example.org/ke#Pollutant#Butte_2023_NO2>,
#         <http://example.org/ke#Pollutant#Butte_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#207172> .
#
# ns1:Cambria_2018 ns1:hasCounty <http://example.org/ke#County#Cambria> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Cambria_2018_CO>,
#         <http://example.org/ke#Pollutant#Cambria_2018_NO2>,
#         <http://example.org/ke#Pollutant#Cambria_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#131478> .
#
# ns1:Cambria_2019 ns1:hasCounty <http://example.org/ke#County#Cambria> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#88.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Cambria_2019_CO>,
#         <http://example.org/ke#Pollutant#Cambria_2019_NO2>,
#         <http://example.org/ke#Pollutant#Cambria_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#130107> .
#
# ns1:Cambria_2020 ns1:hasCounty <http://example.org/ke#County#Cambria> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#89.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Cambria_2020_CO>,
#         <http://example.org/ke#Pollutant#Cambria_2020_NO2>,
#         <http://example.org/ke#Pollutant#Cambria_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#133211> .
#
# ns1:Cambria_2021 ns1:hasCounty <http://example.org/ke#County#Cambria> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#130.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Cambria_2021_CO>,
#         <http://example.org/ke#Pollutant#Cambria_2021_NO2>,
#         <http://example.org/ke#Pollutant#Cambria_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#132237> .
#
# ns1:Cambria_2022 ns1:hasCounty <http://example.org/ke#County#Cambria> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#119.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Cambria_2022_CO>,
#         <http://example.org/ke#Pollutant#Cambria_2022_NO2>,
#         <http://example.org/ke#Pollutant#Cambria_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#131429> .
#
# ns1:Cambria_2023 ns1:hasCounty <http://example.org/ke#County#Cambria> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#187.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Cambria_2023_CO>,
#         <http://example.org/ke#Pollutant#Cambria_2023_NO2>,
#         <http://example.org/ke#Pollutant#Cambria_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#130668> .
#
# ns1:Contra_Costa_2018 ns1:hasCounty <http://example.org/ke#County#Contra_Costa> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Contra_Costa_2018_CO>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2018_NO2>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1150840> .
#
# ns1:Contra_Costa_2019 ns1:hasCounty <http://example.org/ke#County#Contra_Costa> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#129.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Contra_Costa_2019_CO>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2019_NO2>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1152883> .
#
# ns1:Contra_Costa_2020 ns1:hasCounty <http://example.org/ke#County#Contra_Costa> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#197.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Contra_Costa_2020_CO>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2020_NO2>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1166069> .
#
# ns1:Contra_Costa_2021 ns1:hasCounty <http://example.org/ke#County#Contra_Costa> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Contra_Costa_2021_CO>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2021_NO2>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1163941> .
#
# ns1:Contra_Costa_2022 ns1:hasCounty <http://example.org/ke#County#Contra_Costa> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#129.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Contra_Costa_2022_CO>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2022_NO2>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1157019> .
#
# ns1:Contra_Costa_2023 ns1:hasCounty <http://example.org/ke#County#Contra_Costa> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#87.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Contra_Costa_2023_CO>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2023_NO2>,
#         <http://example.org/ke#Pollutant#Contra_Costa_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1155025> .
#
# ns1:Dallas_2018 ns1:hasCounty <http://example.org/ke#County#Dallas> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Dallas_2018_CO>,
#         <http://example.org/ke#Pollutant#Dallas_2018_NO2>,
#         <http://example.org/ke#Pollutant#Dallas_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2629764> .
#
# ns1:Dallas_2019 ns1:hasCounty <http://example.org/ke#County#Dallas> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#143.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Dallas_2019_CO>,
#         <http://example.org/ke#Pollutant#Dallas_2019_NO2>,
#         <http://example.org/ke#Pollutant#Dallas_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2635603> .
#
# ns1:Dallas_2020 ns1:hasCounty <http://example.org/ke#County#Dallas> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#135.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Dallas_2020_CO>,
#         <http://example.org/ke#Pollutant#Dallas_2020_NO2>,
#         <http://example.org/ke#Pollutant#Dallas_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2610112> .
#
# ns1:Dallas_2021 ns1:hasCounty <http://example.org/ke#County#Dallas> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#174.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Dallas_2021_CO>,
#         <http://example.org/ke#Pollutant#Dallas_2021_NO2>,
#         <http://example.org/ke#Pollutant#Dallas_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2588235> .
#
# ns1:Dallas_2022 ns1:hasCounty <http://example.org/ke#County#Dallas> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#148.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Dallas_2022_CO>,
#         <http://example.org/ke#Pollutant#Dallas_2022_NO2>,
#         <http://example.org/ke#Pollutant#Dallas_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2601993> .
#
# ns1:Dallas_2023 ns1:hasCounty <http://example.org/ke#County#Dallas> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#172.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Dallas_2023_CO>,
#         <http://example.org/ke#Pollutant#Dallas_2023_NO2>,
#         <http://example.org/ke#Pollutant#Dallas_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#2606358> .
#
# ns1:El_Paso_2018 ns1:hasCounty <http://example.org/ke#County#El_Paso> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#El_Paso_2018_CO>,
#         <http://example.org/ke#Pollutant#El_Paso_2018_NO2>,
#         <http://example.org/ke#Pollutant#El_Paso_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#835590> .
#
# ns1:El_Paso_2019 ns1:hasCounty <http://example.org/ke#County#El_Paso> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#157.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#El_Paso_2019_CO>,
#         <http://example.org/ke#Pollutant#El_Paso_2019_NO2>,
#         <http://example.org/ke#Pollutant#El_Paso_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#837501> .
#
# ns1:El_Paso_2020 ns1:hasCounty <http://example.org/ke#County#El_Paso> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#192.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#El_Paso_2020_CO>,
#         <http://example.org/ke#Pollutant#El_Paso_2020_NO2>,
#         <http://example.org/ke#Pollutant#El_Paso_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#866606> .
#
# ns1:El_Paso_2021 ns1:hasCounty <http://example.org/ke#County#El_Paso> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#El_Paso_2021_CO>,
#         <http://example.org/ke#Pollutant#El_Paso_2021_NO2>,
#         <http://example.org/ke#Pollutant#El_Paso_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#867499> .
#
# ns1:El_Paso_2022 ns1:hasCounty <http://example.org/ke#County#El_Paso> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#163.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#El_Paso_2022_CO>,
#         <http://example.org/ke#Pollutant#El_Paso_2022_NO2>,
#         <http://example.org/ke#Pollutant#El_Paso_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#867239> .
#
# ns1:El_Paso_2023 ns1:hasCounty <http://example.org/ke#County#El_Paso> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#154.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#El_Paso_2023_CO>,
#         <http://example.org/ke#Pollutant#El_Paso_2023_NO2>,
#         <http://example.org/ke#Pollutant#El_Paso_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#869880> .
#
# ns1:Erie_2018 ns1:hasCounty <http://example.org/ke#County#Erie> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Erie_2018_CO> ;
#     ns1:hasPopulation <http://example.org/ke#Population#919941> .
#
# ns1:Erie_2019 ns1:hasCounty <http://example.org/ke#County#Erie> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#93.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Erie_2019_CO> ;
#     ns1:hasPopulation <http://example.org/ke#Population#918813> .
#
# ns1:Erie_2020 ns1:hasCounty <http://example.org/ke#County#Erie> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#155.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Erie_2020_CO>,
#         <http://example.org/ke#Pollutant#Erie_2020_NO2>,
#         <http://example.org/ke#Pollutant#Erie_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#952342> .
#
# ns1:Erie_2021 ns1:hasCounty <http://example.org/ke#County#Erie> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#101.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Erie_2021_CO> ;
#     ns1:hasPopulation <http://example.org/ke#Population#952912> .
#
# ns1:Erie_2022 ns1:hasCounty <http://example.org/ke#County#Erie> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Erie_2022_CO> ;
#     ns1:hasPopulation <http://example.org/ke#Population#948423> .
#
# ns1:Erie_2023 ns1:hasCounty <http://example.org/ke#County#Erie> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#169.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Erie_2023_CO> ;
#     ns1:hasPopulation <http://example.org/ke#Population#946147> .
#
# ns1:Fresno_2018 ns1:hasCounty <http://example.org/ke#County#Fresno> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Fresno_2018_CO>,
#         <http://example.org/ke#Pollutant#Fresno_2018_NO2>,
#         <http://example.org/ke#Pollutant#Fresno_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#991298> .
#
# ns1:Fresno_2019 ns1:hasCounty <http://example.org/ke#County#Fresno> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#187.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Fresno_2019_CO>,
#         <http://example.org/ke#Pollutant#Fresno_2019_NO2>,
#         <http://example.org/ke#Pollutant#Fresno_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#997847> .
#
# ns1:Fresno_2020 ns1:hasCounty <http://example.org/ke#County#Fresno> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#298.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Fresno_2020_CO>,
#         <http://example.org/ke#Pollutant#Fresno_2020_NO2>,
#         <http://example.org/ke#Pollutant#Fresno_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1009552> .
#
# ns1:Fresno_2021 ns1:hasCounty <http://example.org/ke#County#Fresno> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#278.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Fresno_2021_CO>,
#         <http://example.org/ke#Pollutant#Fresno_2021_NO2>,
#         <http://example.org/ke#Pollutant#Fresno_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1013103> .
#
# ns1:Fresno_2022 ns1:hasCounty <http://example.org/ke#County#Fresno> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#159.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Fresno_2022_CO>,
#         <http://example.org/ke#Pollutant#Fresno_2022_NO2>,
#         <http://example.org/ke#Pollutant#Fresno_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1015359> .
#
# ns1:Fresno_2023 ns1:hasCounty <http://example.org/ke#County#Fresno> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#151.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Fresno_2023_CO>,
#         <http://example.org/ke#Pollutant#Fresno_2023_NO2>,
#         <http://example.org/ke#Pollutant#Fresno_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1017162> .
#
# ns1:Harris_2018 ns1:hasCounty <http://example.org/ke#County#Harris> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harris_2018_CO>,
#         <http://example.org/ke#Pollutant#Harris_2018_NO2>,
#         <http://example.org/ke#Pollutant#Harris_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#4676913> .
#
# ns1:Harris_2019 ns1:hasCounty <http://example.org/ke#County#Harris> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#202.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harris_2019_CO>,
#         <http://example.org/ke#Pollutant#Harris_2019_NO2>,
#         <http://example.org/ke#Pollutant#Harris_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#4709243> .
#
# ns1:Harris_2020 ns1:hasCounty <http://example.org/ke#County#Harris> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#179.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harris_2020_CO>,
#         <http://example.org/ke#Pollutant#Harris_2020_NO2>,
#         <http://example.org/ke#Pollutant#Harris_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#4734792> .
#
# ns1:Harris_2021 ns1:hasCounty <http://example.org/ke#County#Harris> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#179.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harris_2021_CO>,
#         <http://example.org/ke#Pollutant#Harris_2021_NO2>,
#         <http://example.org/ke#Pollutant#Harris_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#4735517> .
#
# ns1:Harris_2022 ns1:hasCounty <http://example.org/ke#County#Harris> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#179.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harris_2022_CO>,
#         <http://example.org/ke#Pollutant#Harris_2022_NO2>,
#         <http://example.org/ke#Pollutant#Harris_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#4781337> .
#
# ns1:Harris_2023 ns1:hasCounty <http://example.org/ke#County#Harris> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#205.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harris_2023_CO>,
#         <http://example.org/ke#Pollutant#Harris_2023_NO2>,
#         <http://example.org/ke#Pollutant#Harris_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#4835125> .
#
# ns1:Harrison_2018 ns1:hasCounty <http://example.org/ke#County#Harrison> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harrison_2018_NO2>,
#         <http://example.org/ke#Pollutant#Harrison_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#66693> .
#
# ns1:Harrison_2019 ns1:hasCounty <http://example.org/ke#County#Harrison> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#90.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harrison_2019_NO2>,
#         <http://example.org/ke#Pollutant#Harrison_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#66484> .
#
# ns1:Harrison_2020 ns1:hasCounty <http://example.org/ke#County#Harrison> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#100.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harrison_2020_NO2>,
#         <http://example.org/ke#Pollutant#Harrison_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#68801> .
#
# ns1:Harrison_2021 ns1:hasCounty <http://example.org/ke#County#Harrison> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#158.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harrison_2021_NO2>,
#         <http://example.org/ke#Pollutant#Harrison_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#69527> .
#
# ns1:Harrison_2022 ns1:hasCounty <http://example.org/ke#County#Harrison> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#173.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harrison_2022_NO2>,
#         <http://example.org/ke#Pollutant#Harrison_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#70038> .
#
# ns1:Harrison_2023 ns1:hasCounty <http://example.org/ke#County#Harrison> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#111.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Harrison_2023_NO2>,
#         <http://example.org/ke#Pollutant#Harrison_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#70895> .
#
# ns1:Humboldt_2018 ns1:hasCounty <http://example.org/ke#County#Humboldt> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Humboldt_2018_CO>,
#         <http://example.org/ke#Pollutant#Humboldt_2018_NO2>,
#         <http://example.org/ke#Pollutant#Humboldt_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#136502> .
#
# ns1:Humboldt_2019 ns1:hasCounty <http://example.org/ke#County#Humboldt> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#65.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Humboldt_2019_CO>,
#         <http://example.org/ke#Pollutant#Humboldt_2019_NO2>,
#         <http://example.org/ke#Pollutant#Humboldt_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#135839> .
#
# ns1:Humboldt_2020 ns1:hasCounty <http://example.org/ke#County#Humboldt> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#109.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Humboldt_2020_CO>,
#         <http://example.org/ke#Pollutant#Humboldt_2020_NO2>,
#         <http://example.org/ke#Pollutant#Humboldt_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#136262> .
#
# ns1:Humboldt_2021 ns1:hasCounty <http://example.org/ke#County#Humboldt> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#60.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Humboldt_2021_CO>,
#         <http://example.org/ke#Pollutant#Humboldt_2021_NO2>,
#         <http://example.org/ke#Pollutant#Humboldt_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#134897> .
#
# ns1:Humboldt_2022 ns1:hasCounty <http://example.org/ke#County#Humboldt> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#70.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Humboldt_2022_CO>,
#         <http://example.org/ke#Pollutant#Humboldt_2022_NO2>,
#         <http://example.org/ke#Pollutant#Humboldt_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#134944> .
#
# ns1:Humboldt_2023 ns1:hasCounty <http://example.org/ke#County#Humboldt> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#274.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Humboldt_2023_CO>,
#         <http://example.org/ke#Pollutant#Humboldt_2023_NO2>,
#         <http://example.org/ke#Pollutant#Humboldt_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#133985> .
#
# ns1:Imperial_2018 ns1:hasCounty <http://example.org/ke#County#Imperial> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Imperial_2018_CO>,
#         <http://example.org/ke#Pollutant#Imperial_2018_NO2>,
#         <http://example.org/ke#Pollutant#Imperial_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#181062> .
#
# ns1:Imperial_2019 ns1:hasCounty <http://example.org/ke#County#Imperial> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#185.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Imperial_2019_CO>,
#         <http://example.org/ke#Pollutant#Imperial_2019_NO2>,
#         <http://example.org/ke#Pollutant#Imperial_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#180439> .
#
# ns1:Imperial_2020 ns1:hasCounty <http://example.org/ke#County#Imperial> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#166.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Imperial_2020_CO>,
#         <http://example.org/ke#Pollutant#Imperial_2020_NO2>,
#         <http://example.org/ke#Pollutant#Imperial_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#179612> .
#
# ns1:Imperial_2021 ns1:hasCounty <http://example.org/ke#County#Imperial> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#442.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Imperial_2021_CO>,
#         <http://example.org/ke#Pollutant#Imperial_2021_NO2>,
#         <http://example.org/ke#Pollutant#Imperial_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#179138> .
#
# ns1:Imperial_2022 ns1:hasCounty <http://example.org/ke#County#Imperial> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#762.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Imperial_2022_CO>,
#         <http://example.org/ke#Pollutant#Imperial_2022_NO2>,
#         <http://example.org/ke#Pollutant#Imperial_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#178940> .
#
# ns1:Imperial_2023 ns1:hasCounty <http://example.org/ke#County#Imperial> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#505.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Imperial_2023_CO>,
#         <http://example.org/ke#Pollutant#Imperial_2023_NO2>,
#         <http://example.org/ke#Pollutant#Imperial_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#179057> .
#
# ns1:Jefferson_2018 ns1:hasCounty <http://example.org/ke#County#Jefferson> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Jefferson_2018_CO>,
#         <http://example.org/ke#Pollutant#Jefferson_2018_NO2>,
#         <http://example.org/ke#Pollutant#Jefferson_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#252655> .
#
# ns1:Jefferson_2019 ns1:hasCounty <http://example.org/ke#County#Jefferson> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Jefferson_2019_NO2>,
#         <http://example.org/ke#Pollutant#Jefferson_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#251315> .
#
# ns1:Jefferson_2020 ns1:hasCounty <http://example.org/ke#County#Jefferson> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#122.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Jefferson_2020_NO2>,
#         <http://example.org/ke#Pollutant#Jefferson_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#256133> .
#
# ns1:Jefferson_2021 ns1:hasCounty <http://example.org/ke#County#Jefferson> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#115.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Jefferson_2021_NO2>,
#         <http://example.org/ke#Pollutant#Jefferson_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#253727> .
#
# ns1:Jefferson_2022 ns1:hasCounty <http://example.org/ke#County#Jefferson> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#129.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Jefferson_2022_NO2>,
#         <http://example.org/ke#Pollutant#Jefferson_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#251601> .
#
# ns1:Jefferson_2023 ns1:hasCounty <http://example.org/ke#County#Jefferson> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#122.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Jefferson_2023_NO2>,
#         <http://example.org/ke#Pollutant#Jefferson_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#251496> .
#
# ns1:Kern_2018 ns1:hasCounty <http://example.org/ke#County#Kern> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Kern_2018_CO>,
#         <http://example.org/ke#Pollutant#Kern_2018_NO2>,
#         <http://example.org/ke#Pollutant#Kern_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#893618> .
#
# ns1:Kern_2019 ns1:hasCounty <http://example.org/ke#County#Kern> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#548.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Kern_2019_CO>,
#         <http://example.org/ke#Pollutant#Kern_2019_NO2>,
#         <http://example.org/ke#Pollutant#Kern_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#898898> .
#
# ns1:Kern_2020 ns1:hasCounty <http://example.org/ke#County#Kern> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#267.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Kern_2020_CO>,
#         <http://example.org/ke#Pollutant#Kern_2020_NO2>,
#         <http://example.org/ke#Pollutant#Kern_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#905910> .
#
# ns1:Kern_2021 ns1:hasCounty <http://example.org/ke#County#Kern> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#316.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Kern_2021_CO>,
#         <http://example.org/ke#Pollutant#Kern_2021_NO2>,
#         <http://example.org/ke#Pollutant#Kern_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#912709> .
#
# ns1:Kern_2022 ns1:hasCounty <http://example.org/ke#County#Kern> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#289.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Kern_2022_CO>,
#         <http://example.org/ke#Pollutant#Kern_2022_NO2>,
#         <http://example.org/ke#Pollutant#Kern_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#916751> .
#
# ns1:Kern_2023 ns1:hasCounty <http://example.org/ke#County#Kern> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#111.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Kern_2023_CO>,
#         <http://example.org/ke#Pollutant#Kern_2023_NO2>,
#         <http://example.org/ke#Pollutant#Kern_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#913820> .
#
# ns1:Lackawanna_2018 ns1:hasCounty <http://example.org/ke#County#Lackawanna> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Lackawanna_2018_CO>,
#         <http://example.org/ke#Pollutant#Lackawanna_2018_NO2>,
#         <http://example.org/ke#Pollutant#Lackawanna_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#210301> .
#
# ns1:Lackawanna_2019 ns1:hasCounty <http://example.org/ke#County#Lackawanna> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#80.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Lackawanna_2019_CO>,
#         <http://example.org/ke#Pollutant#Lackawanna_2019_NO2>,
#         <http://example.org/ke#Pollutant#Lackawanna_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#209808> .
#
# ns1:Lackawanna_2020 ns1:hasCounty <http://example.org/ke#County#Lackawanna> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#81.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Lackawanna_2020_CO>,
#         <http://example.org/ke#Pollutant#Lackawanna_2020_NO2>,
#         <http://example.org/ke#Pollutant#Lackawanna_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#215539> .
#
# ns1:Lackawanna_2021 ns1:hasCounty <http://example.org/ke#County#Lackawanna> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#137.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Lackawanna_2021_CO>,
#         <http://example.org/ke#Pollutant#Lackawanna_2021_NO2>,
#         <http://example.org/ke#Pollutant#Lackawanna_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#216043> .
#
# ns1:Lackawanna_2022 ns1:hasCounty <http://example.org/ke#County#Lackawanna> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#71.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Lackawanna_2022_CO>,
#         <http://example.org/ke#Pollutant#Lackawanna_2022_NO2>,
#         <http://example.org/ke#Pollutant#Lackawanna_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#215750> .
#
# ns1:Lackawanna_2023 ns1:hasCounty <http://example.org/ke#County#Lackawanna> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#268.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Lackawanna_2023_CO>,
#         <http://example.org/ke#Pollutant#Lackawanna_2023_NO2>,
#         <http://example.org/ke#Pollutant#Lackawanna_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#216123> .
#
# ns1:Los_Angeles_2018 ns1:hasCounty <http://example.org/ke#County#Los_Angeles> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Los_Angeles_2018_CO>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2018_NO2>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#10061533> .
#
# ns1:Los_Angeles_2019 ns1:hasCounty <http://example.org/ke#County#Los_Angeles> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#201.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Los_Angeles_2019_CO>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2019_NO2>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#10011602> .
#
# ns1:Los_Angeles_2020 ns1:hasCounty <http://example.org/ke#County#Los_Angeles> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#235.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Los_Angeles_2020_CO>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2020_NO2>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#9992813> .
#
# ns1:Los_Angeles_2021 ns1:hasCounty <http://example.org/ke#County#Los_Angeles> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#281.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Los_Angeles_2021_CO>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2021_NO2>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#9809462> .
#
# ns1:Los_Angeles_2022 ns1:hasCounty <http://example.org/ke#County#Los_Angeles> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#209.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Los_Angeles_2022_CO>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2022_NO2>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#9719765> .
#
# ns1:Los_Angeles_2023 ns1:hasCounty <http://example.org/ke#County#Los_Angeles> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#192.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Los_Angeles_2023_CO>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2023_NO2>,
#         <http://example.org/ke#Pollutant#Los_Angeles_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#9663345> .
#
# ns1:Madera_2018 ns1:hasCounty <http://example.org/ke#County#Madera> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Madera_2018_CO>,
#         <http://example.org/ke#Pollutant#Madera_2018_NO2>,
#         <http://example.org/ke#Pollutant#Madera_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#156373> .
#
# ns1:Madera_2019 ns1:hasCounty <http://example.org/ke#County#Madera> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#140.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Madera_2019_NO2>,
#         <http://example.org/ke#Pollutant#Madera_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#156717> .
#
# ns1:Madera_2020 ns1:hasCounty <http://example.org/ke#County#Madera> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#250.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Madera_2020_NO2>,
#         <http://example.org/ke#Pollutant#Madera_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#156345> .
#
# ns1:Madera_2021 ns1:hasCounty <http://example.org/ke#County#Madera> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#194.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Madera_2021_NO2>,
#         <http://example.org/ke#Pollutant#Madera_2021_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#158966> .
#
# ns1:Madera_2022 ns1:hasCounty <http://example.org/ke#County#Madera> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#136.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Madera_2022_NO2>,
#         <http://example.org/ke#Pollutant#Madera_2022_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#160329> .
#
# ns1:Madera_2023 ns1:hasCounty <http://example.org/ke#County#Madera> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#216.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Madera_2023_NO2>,
#         <http://example.org/ke#Pollutant#Madera_2023_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#162858> .
#
# ns1:Monroe_2018 ns1:hasCounty <http://example.org/ke#County#Monroe> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Monroe_2018_CO> ;
#     ns1:hasPopulation <http://example.org/ke#Population#744239> .
#
# ns1:Monroe_2019 ns1:hasCounty <http://example.org/ke#County#Monroe> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#90.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Monroe_2019_CO> ;
#     ns1:hasPopulation <http://example.org/ke#Population#742605> .
#
# ns1:Monroe_2020 ns1:hasCounty <http://example.org/ke#County#Monroe> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#80.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Monroe_2020_CO>,
#         <http://example.org/ke#Pollutant#Monroe_2020_NO2>,
#         <http://example.org/ke#Pollutant#Monroe_2020_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#757551> .
#
# ns1:Monroe_2021 ns1:hasCounty <http://example.org/ke#County#Monroe> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#100.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Monroe_2021_CO> ;
#     ns1:hasPopulation <http://example.org/ke#Population#755813> .
#
# ns1:Monroe_2022 ns1:hasCounty <http://example.org/ke#County#Monroe> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#126.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Monroe_2022_CO> ;
#     ns1:hasPopulation <http://example.org/ke#Population#750887> .
#
# ns1:Monroe_2023 ns1:hasCounty <http://example.org/ke#County#Monroe> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#170.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Monroe_2023_CO> ;
#     ns1:hasPopulation <http://example.org/ke#Population#748482> .
#
# ns1:Philadelphia_2018 ns1:hasCounty <http://example.org/ke#County#Philadelphia> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#150.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Philadelphia_2018_CO>,
#         <http://example.org/ke#Pollutant#Philadelphia_2018_NO2>,
#         <http://example.org/ke#Pollutant#Philadelphia_2018_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1586422> .
#
# ns1:Philadelphia_2019 ns1:hasCounty <http://example.org/ke#County#Philadelphia> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#140.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Philadelphia_2019_CO>,
#         <http://example.org/ke#Pollutant#Philadelphia_2019_NO2>,
#         <http://example.org/ke#Pollutant#Philadelphia_2019_PM2.5> ;
#     ns1:hasPopulation <http://example.org/ke#Population#1584439> .
#
# ns1:Philadelphia_2020 ns1:hasCounty <http://example.org/ke#County#Philadelphia> ;
#     ns1:hasMaxAQI <http://example.org/ke#AQI#119.0> ;
#     ns1:hasPollutant <http://example.org/ke#Pollutant#Philadelphia_2020_CO>,
#         <http://example.org/ke#Pollutant#Philadelphia_2020_NO2>,
# ...
#
# <http://example.org/ke#Pollutant#Los_Angeles_2021_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4879032258064516> .
#
# <http://example.org/ke#Pollutant#Los_Angeles_2021_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#25.729291674063557> .
#
# <http://example.org/ke#Pollutant#Los_Angeles_2021_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#12.454339143064631> .
#
# <http://example.org/ke#Pollutant#Los_Angeles_2022_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4727993206906312> .
#
# <http://example.org/ke#Pollutant#Los_Angeles_2022_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#25.870868504970925> .
#
# <http://example.org/ke#Pollutant#Los_Angeles_2022_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#10.971637080867849> .
#
# <http://example.org/ke#Pollutant#Los_Angeles_2023_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4417693522906793> .
#
# <http://example.org/ke#Pollutant#Los_Angeles_2023_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#22.78451536643026> .
#
# <http://example.org/ke#Pollutant#Los_Angeles_2023_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#10.078864809081526> .
#
# <http://example.org/ke#Pollutant#Madera_2018_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.2481792717086835> .
#
# <http://example.org/ke#Pollutant#Madera_2018_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#12.641225626740946> .
#
# <http://example.org/ke#Pollutant#Madera_2018_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#14.116042780748662> .
#
# <http://example.org/ke#Pollutant#Madera_2019_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#12.476685393258428> .
#
# <http://example.org/ke#Pollutant#Madera_2019_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#9.612885154061626> .
#
# <http://example.org/ke#Pollutant#Madera_2020_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#12.86923076923077> .
#
# <http://example.org/ke#Pollutant#Madera_2020_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#17.067848101265824> .
#
# <http://example.org/ke#Pollutant#Madera_2021_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#11.916759776536312> .
#
# <http://example.org/ke#Pollutant#Madera_2021_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#12.398879551820729> .
#
# <http://example.org/ke#Pollutant#Madera_2022_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#12.461944444444445> .
#
# <http://example.org/ke#Pollutant#Madera_2022_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#10.386388888888888> .
#
# <http://example.org/ke#Pollutant#Madera_2023_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#10.910584958217273> .
#
# <http://example.org/ke#Pollutant#Madera_2023_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#9.941274238227148> .
#
# <http://example.org/ke#Pollutant#Monroe_2018_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.3110650069156293> .
#
# <http://example.org/ke#Pollutant#Monroe_2019_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.304055944055944> .
#
# <http://example.org/ke#Pollutant#Monroe_2020_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.2764044943820224> .
#
# <http://example.org/ke#Pollutant#Monroe_2020_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#12.578547854785478> .
#
# <http://example.org/ke#Pollutant#Monroe_2020_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#6.088013411567477> .
#
# <http://example.org/ke#Pollutant#Monroe_2021_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.2905292479108635> .
#
# <http://example.org/ke#Pollutant#Monroe_2022_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.2814447592067988> .
#
# <http://example.org/ke#Pollutant#Monroe_2023_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.31321044546851> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2018_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4784822286263209> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2018_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#20.022155688622757> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2018_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.817489711934156> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2019_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4815206929740135> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2019_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#24.066425120772948> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2019_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.200228832951945> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2020_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.5161319890009166> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2020_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#22.837047353760447> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2020_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#7.497890733056709> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2021_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.5001838235294118> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2021_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#24.003075489282384> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2021_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#9.404932537049325> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2022_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4809833024118738> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2022_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#24.32075471698113> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2022_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.222641129032258> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2023_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.5020128087831657> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2023_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#24.579564806054872> .
#
# <http://example.org/ke#Pollutant#Philadelphia_2023_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#12.197723745473358> .
#
# <http://example.org/ke#Pollutant#Tarrant_2018_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4706849315068493> .
#
# <http://example.org/ke#Pollutant#Tarrant_2018_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#17.64032258064516> .
#
# <http://example.org/ke#Pollutant#Tarrant_2018_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.769153225806452> .
#
# <http://example.org/ke#Pollutant#Tarrant_2019_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4642659279778393> .
#
# <http://example.org/ke#Pollutant#Tarrant_2019_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#17.991129643669446> .
#
# <http://example.org/ke#Pollutant#Tarrant_2019_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.783619817997979> .
#
# <http://example.org/ke#Pollutant#Tarrant_2020_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4286885245901639> .
#
# <http://example.org/ke#Pollutant#Tarrant_2020_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#16.19875419262099> .
#
# <http://example.org/ke#Pollutant#Tarrant_2020_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.828057553956835> .
#
# <http://example.org/ke#Pollutant#Tarrant_2021_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4889196675900277> .
#
# <http://example.org/ke#Pollutant#Tarrant_2021_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#17.81577164973391> .
#
# <http://example.org/ke#Pollutant#Tarrant_2021_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#9.03142235123367> .
#
# <http://example.org/ke#Pollutant#Tarrant_2022_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4420329670329671> .
#
# <http://example.org/ke#Pollutant#Tarrant_2022_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#18.52365591397849> .
#
# <http://example.org/ke#Pollutant#Tarrant_2022_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.80228734810579> .
#
# <http://example.org/ke#Pollutant#Tarrant_2023_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4737142857142857> .
#
# <http://example.org/ke#Pollutant#Tarrant_2023_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#18.78756027000964> .
#
# <http://example.org/ke#Pollutant#Tarrant_2023_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#10.228328402366865> .
#
# <http://example.org/ke#Pollutant#Travis_2018_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.4684931506849315> .
#
# <http://example.org/ke#Pollutant#Travis_2018_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#17.14613259668508> .
#
# <http://example.org/ke#Pollutant#Travis_2018_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.554565456545655> .
#
# <http://example.org/ke#Pollutant#Travis_2019_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.5008219178082192> .
#
# <http://example.org/ke#Pollutant#Travis_2019_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#16.31578947368421> .
#
# <http://example.org/ke#Pollutant#Travis_2019_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.58219557195572> .
#
# <http://example.org/ke#Pollutant#Travis_2020_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.5854794520547945> .
#
# <http://example.org/ke#Pollutant#Travis_2020_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#20.461746361746364> .
#
# <http://example.org/ke#Pollutant#Travis_2020_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.888783943329399> .
#
# <http://example.org/ke#Pollutant#Travis_2021_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.6019178082191781> .
#
# <http://example.org/ke#Pollutant#Travis_2021_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#16.23140028288543> .
#
# <http://example.org/ke#Pollutant#Travis_2021_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.864828897338402> .
#
# <http://example.org/ke#Pollutant#Travis_2022_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.5632302405498282> .
#
# <http://example.org/ke#Pollutant#Travis_2022_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#16.470209059233447> .
#
# <http://example.org/ke#Pollutant#Travis_2022_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.676617375231054> .
#
# <http://example.org/ke#Pollutant#Travis_2023_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.5994134897360704> .
#
# <http://example.org/ke#Pollutant#Travis_2023_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#17.71965517241379> .
#
# <http://example.org/ke#Pollutant#Travis_2023_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#10.04275092936803> .
#
# <http://example.org/ke#Pollutant#York_2018_CO> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#0.341025641025641> .
#
# <http://example.org/ke#Pollutant#York_2018_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#16.50194552529183> .
#
# <http://example.org/ke#Pollutant#York_2018_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#9.645555555555555> .
#
# <http://example.org/ke#Pollutant#York_2019_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#18.91111111111111> .
#
# <http://example.org/ke#Pollutant#York_2019_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.629359823399557> .
#
# <http://example.org/ke#Pollutant#York_2020_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#17.936599423631122> .
#
# <http://example.org/ke#Pollutant#York_2020_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.80799418604651> .
#
# <http://example.org/ke#Pollutant#York_2021_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#19.30952380952381> .
#
# <http://example.org/ke#Pollutant#York_2021_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#10.304755043227663> .
#
# <http://example.org/ke#Pollutant#York_2022_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#19.30819209039548> .
#
# <http://example.org/ke#Pollutant#York_2022_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#8.44112676056338> .
#
# <http://example.org/ke#Pollutant#York_2023_NO2> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#19.51964809384164> .
#
# <http://example.org/ke#Pollutant#York_2023_PM2.5> ns1:hasConcentration <http://example.org/ke#PollutantConcentration#11.435984095427436> .
#
# <http://example.org/ke#County#Adams> ns1:hasRUCC <http://example.org/ke#RUCC#3.0> .
#
# <http://example.org/ke#County#Alameda> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Allegheny> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Bexar> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Butte> ns1:hasRUCC <http://example.org/ke#RUCC#3.0> .
#
# <http://example.org/ke#County#Cambria> ns1:hasRUCC <http://example.org/ke#RUCC#3.0> .
#
# <http://example.org/ke#County#Contra_Costa> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Dallas> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#El_Paso> ns1:hasRUCC <http://example.org/ke#RUCC#2.0> .
#
# <http://example.org/ke#County#Erie> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Fresno> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Harris> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Harrison> ns1:hasRUCC <http://example.org/ke#RUCC#2.0> .
#
# <http://example.org/ke#County#Humboldt> ns1:hasRUCC <http://example.org/ke#RUCC#5.0> .
#
# <http://example.org/ke#County#Imperial> ns1:hasRUCC <http://example.org/ke#RUCC#3.0> .
#
# <http://example.org/ke#County#Jefferson> ns1:hasRUCC <http://example.org/ke#RUCC#2.0> .
#
# <http://example.org/ke#County#Kern> ns1:hasRUCC <http://example.org/ke#RUCC#2.0> .
#
# <http://example.org/ke#County#Lackawanna> ns1:hasRUCC <http://example.org/ke#RUCC#2.0> .
#
# <http://example.org/ke#County#Los_Angeles> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Madera> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Monroe> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Philadelphia> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Tarrant> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#Travis> ns1:hasRUCC <http://example.org/ke#RUCC#1.0> .
#
# <http://example.org/ke#County#York> ns1:hasRUCC <http://example.org/ke#RUCC#2.0> .

# %%
from pyvis.network import Network
net = Network(height='750px', width='100%', directed=True, neighborhood_highlight=True)

# Add nodes and edges to the network
for subject, predicate, object in g:
    subject_label = str(subject).split("#")[-1]
    predicate_label = str(predicate).split("#")[-1]
    object_label = str(object).split("#")[-1]
    
    subject_type = str(subject).split("#")[-2]
    object_type = str(object).split("#")[-2]
    print(subject_label, predicate_label, object_label)    
    if subject_label not in net.node_ids:
        if "ke" in subject_type:
            subject_title = subject_label
        else:
            subject_title = subject_type + ": " + subject_label
        net.add_node(subject_label, 
                     label=subject_label, 
                     title=subject_title, 
                     labelHighlightBold=True)
        
    if object_label not in net.node_ids:
        if "ke" in object_type:
            object_title = object_label
        else:
            object_title = object_type + ": " + object_label
            
        net.add_node(object_label, 
                     label=object_label, 
                     title=object_title, 
                     labelHighlightBold=True)

    edge_color = {
        'hasState': 'red',
        'hasRUCC': 'black',
        'hasCounty': 'orange',
        'hasPopulation': 'green',
        'hasMaxAQI': 'blue',
        'hasPollutant': 'pink',
        'hasConcentration': 'purple',
    }.get(predicate_label, 'grey')
        
    net.add_edge(subject_label, 
                     object_label, 
                     title=predicate_label, 
                     label=predicate_label, 
                     color=edge_color)
    
# # Show the network
net.save_graph(os.path.join(results_path, "Q2.html"))
net.show("Q2.html", local=False, notebook=False)
# Out:
# Contra_Costa_2023 hasPollutant Contra_Costa_2023_NO2
# Alameda_2022 hasPollutant Alameda_2022_NO2
# Dallas_2020 hasMaxAQI 135.0
# Bexar_2021_NO2 hasConcentration 10.794186046511628
# Fresno_2021_PM2.5 hasConcentration 12.830191404839294
# Cambria_2018 hasPopulation 131478
# Fresno_2023_NO2 hasConcentration 17.91797806390081
# Harris_2020 hasPopulation 4734792
# Lackawanna_2021 hasMaxAQI 137.0
# Humboldt_2019 hasCounty Humboldt
# Kern_2019_CO hasConcentration 0.3266483516483516
# Fresno_2022 hasCounty Fresno
# Butte_2022 hasPollutant Butte_2022_NO2
# Cambria_2022_NO2 hasConcentration 13.659604519774012
# York_2021_PM2.5 hasConcentration 10.304755043227663
# Lackawanna_2022 hasPollutant Lackawanna_2022_PM2.5
# Texas hasState Bexar
# Alameda_2018_NO2 hasConcentration 22.769899183869416
# El_Paso_2023 hasPopulation 869880
# Cambria_2023 hasPollutant Cambria_2023_PM2.5
# Harrison_2019 hasPollutant Harrison_2019_NO2
# Jefferson_2020 hasCounty Jefferson
# Imperial_2022 hasPollutant Imperial_2022_NO2
# Contra_Costa_2020 hasPollutant Contra_Costa_2020_CO
# Madera_2023 hasPollutant Madera_2023_PM2.5
# Harris_2021 hasPollutant Harris_2021_CO
# Tarrant_2019 hasMaxAQI 147.0
# Alameda_2018 hasPollutant Alameda_2018_CO
# Travis_2020_PM2.5 hasConcentration 8.888783943329399
# Imperial_2023_NO2 hasConcentration 20.240529247910864
# Dallas_2023_NO2 hasConcentration 18.30628058727569
# Harrison_2020 hasPopulation 68801
# Humboldt_2019 hasPollutant Humboldt_2019_PM2.5
# Jefferson_2018_PM2.5 hasConcentration 9.643296089385476
# California hasState Imperial
# Madera_2023 hasMaxAQI 216.0
# Fresno_2023 hasPollutant Fresno_2023_CO
# Los_Angeles_2023 hasCounty Los_Angeles
# York_2020_NO2 hasConcentration 17.936599423631122
# Jefferson_2018 hasMaxAQI 150.0
# Cambria_2021 hasPopulation 132237
# Butte_2023 hasPollutant Butte_2023_NO2
# California hasState Kern
# California hasState Alameda
# Monroe_2020 hasPollutant Monroe_2020_CO
# Cambria_2021_CO hasConcentration 0.2436260623229461
# Jefferson_2023_PM2.5 hasConcentration 9.7521113243762
# Alameda_2022 hasMaxAQI 122.0
# Dallas_2021 hasMaxAQI 174.0
# Jefferson_2023 hasCounty Jefferson
# Bexar_2018 hasPollutant Bexar_2018_CO
# Bexar_2019 hasMaxAQI 169.0
# Imperial_2023 hasMaxAQI 505.0
# El_Paso_2023 hasPollutant El_Paso_2023_PM2.5
# Lackawanna_2023 hasCounty Lackawanna
# Philadelphia_2022 hasPollutant Philadelphia_2022_PM2.5
# Humboldt_2023 hasPopulation 133985
# Kern_2023 hasCounty Kern
# Los_Angeles_2023_NO2 hasConcentration 22.78451536643026
# Adams_2019_NO2 hasConcentration 3.807073954983923
# Tarrant_2020 hasPopulation 2115840
# Imperial_2023 hasPollutant Imperial_2023_CO
# Philadelphia_2018_NO2 hasConcentration 20.022155688622757
# Alameda_2020 hasCounty Alameda
# Dallas_2020 hasCounty Dallas
# Tarrant_2019 hasPollutant Tarrant_2019_CO
# Madera_2020_NO2 hasConcentration 12.86923076923077
# Los_Angeles_2020_NO2 hasConcentration 25.827116864940518
# Harrison_2023 hasMaxAQI 111.0
# Harrison_2023 hasPollutant Harrison_2023_PM2.5
# Allegheny_2022 hasPollutant Allegheny_2022_CO
# Philadelphia_2022 hasCounty Philadelphia
# Kern_2018 hasPollutant Kern_2018_PM2.5
# Alameda_2022_PM2.5 hasConcentration 8.198047964305633
# Fresno_2022_CO hasConcentration 0.5055961070559611
# Fresno_2018 hasCounty Fresno
# Lackawanna_2018 hasMaxAQI 150.0
# Contra_Costa_2019 hasMaxAQI 129.0
# Philadelphia_2019 hasMaxAQI 140.0
# Allegheny_2019 hasMaxAQI 161.0
# Fresno_2018_PM2.5 hasConcentration 13.157697740112994
# Tarrant_2020 hasMaxAQI 159.0
# Lackawanna_2023 hasPollutant Lackawanna_2023_NO2
# Imperial_2021_CO hasConcentration 0.5178571428571429
# Kern_2019 hasPollutant Kern_2019_PM2.5
# Kern_2022 hasPollutant Kern_2022_PM2.5
# Adams_2019_PM2.5 hasConcentration 8.635114503816794
# Lackawanna_2021_NO2 hasConcentration 24.797101449275363
# Philadelphia_2021 hasPollutant Philadelphia_2021_CO
# Madera_2023 hasPollutant Madera_2023_NO2
# Butte_2020 hasPollutant Butte_2020_CO
# Contra_Costa_2019 hasPopulation 1152883
# Cambria_2021_NO2 hasConcentration 13.1875
# Travis_2022 hasPopulation 1327550
# Travis_2018 hasPollutant Travis_2018_NO2
# Bexar_2020_PM2.5 hasConcentration 8.789470404984424
# Erie_2018 hasMaxAQI 150.0
# Fresno_2020 hasCounty Fresno
# Madera_2023_PM2.5 hasConcentration 9.941274238227148
# Lackawanna_2022 hasPopulation 215750
# Kern_2023_NO2 hasConcentration 21.416769144773617
# Humboldt_2020 hasCounty Humboldt
# Lackawanna_2018 hasCounty Lackawanna
# Harris_2019 hasPollutant Harris_2019_PM2.5
# Allegheny_2021 hasPollutant Allegheny_2021_CO
# Tarrant_2021 hasPopulation 2129695
# Adams_2018 hasPollutant Adams_2018_CO
# El_Paso hasRUCC 2.0
# Adams_2022_PM2.5 hasConcentration 8.005479452054795
# Adams_2021 hasPollutant Adams_2021_NO2
# York_2020_PM2.5 hasConcentration 8.80799418604651
# Imperial_2021_PM2.5 hasConcentration 8.843570347957641
# Philadelphia_2023_PM2.5 hasConcentration 12.197723745473358
# Contra_Costa_2021 hasMaxAQI 150.0
# Cambria_2022 hasMaxAQI 119.0
# Imperial_2018 hasPollutant Imperial_2018_PM2.5
# Harrison_2021 hasPopulation 69527
# Philadelphia_2019_PM2.5 hasConcentration 8.200228832951945
# Dallas_2022 hasCounty Dallas
# Butte_2020 hasPollutant Butte_2020_PM2.5
# Allegheny_2018 hasMaxAQI 150.0
# Monroe_2021 hasPollutant Monroe_2021_CO
# Contra_Costa_2022_CO hasConcentration 0.3966666666666666
# Adams_2018 hasCounty Adams
# Los_Angeles_2022 hasPopulation 9719765
# Alameda_2023 hasCounty Alameda
# Cambria_2019 hasPollutant Cambria_2019_CO
# Contra_Costa_2020 hasPollutant Contra_Costa_2020_NO2
# Cambria_2023 hasMaxAQI 187.0
# Jefferson_2021_NO2 hasConcentration 9.715456674473067
# Los_Angeles_2020 hasPopulation 9992813
# Travis_2020 hasCounty Travis
# Imperial_2019 hasMaxAQI 185.0
# Tarrant hasRUCC 1.0
# Monroe_2020 hasMaxAQI 80.0
# Alameda_2019 hasCounty Alameda
# Butte_2018_PM2.5 hasConcentration 14.488928317956
# Humboldt_2022 hasPopulation 134944
# Fresno_2020 hasPollutant Fresno_2020_CO
# Harris_2020_CO hasConcentration 0.4021937842778793
# Jefferson_2021_PM2.5 hasConcentration 7.429936305732484
# Adams_2018 hasPollutant Adams_2018_NO2
# Erie_2018 hasCounty Erie
# Kern_2023 hasMaxAQI 111.0
# Bexar_2019 hasPollutant Bexar_2019_CO
# Fresno_2020_CO hasConcentration 0.554066985645933
# Alameda_2018 hasMaxAQI 150.0
# Bexar_2020 hasPopulation 2015501
# Dallas_2020_PM2.5 hasConcentration 8.319458544839256
# Cambria_2020_NO2 hasConcentration 13.150769230769232
# Fresno_2022_NO2 hasConcentration 19.959630856601983
# Contra_Costa_2022 hasPollutant Contra_Costa_2022_PM2.5
# Kern_2020 hasPollutant Kern_2020_NO2
# Madera_2019 hasPopulation 156717
# Humboldt_2021_PM2.5 hasConcentration 6.920869565217391
# Tarrant_2021 hasPollutant Tarrant_2021_NO2
# Monroe_2020 hasPollutant Monroe_2020_NO2
# Madera_2019 hasMaxAQI 140.0
# Texas hasState El_Paso
# Lackawanna_2019 hasMaxAQI 80.0
# Los_Angeles_2019 hasMaxAQI 201.0
# Dallas hasRUCC 1.0
# Los_Angeles_2018 hasPollutant Los_Angeles_2018_CO
# Humboldt_2023_PM2.5 hasConcentration 11.66902985074627
# Alameda_2018 hasCounty Alameda
# Philadelphia_2019_CO hasConcentration 0.4815206929740135
# Harrison_2023 hasPopulation 70895
# El_Paso_2019 hasMaxAQI 157.0
# Alameda hasRUCC 1.0
# Dallas_2019_NO2 hasConcentration 17.41407914764079
# Dallas_2018 hasPollutant Dallas_2018_CO
# Alameda_2019_NO2 hasConcentration 21.40172253258845
# Imperial_2018_NO2 hasConcentration 23.41910331384016
# Harris_2020_PM2.5 hasConcentration 9.726361341507394
# Fresno_2021_CO hasConcentration 0.5073818897637795
# Tarrant_2023 hasCounty Tarrant
# Dallas_2019 hasPollutant Dallas_2019_PM2.5
# Kern_2023 hasPollutant Kern_2023_NO2
# El_Paso_2021 hasPollutant El_Paso_2021_PM2.5
# Cambria_2021 hasPollutant Cambria_2021_PM2.5
# Cambria_2020_PM2.5 hasConcentration 8.049725274725274
# Philadelphia_2019 hasPopulation 1584439
# Contra_Costa_2022 hasPopulation 1157019
# El_Paso_2022 hasCounty El_Paso
# Kern_2020_CO hasConcentration 0.4061046511627906
# Fresno_2023 hasMaxAQI 151.0
# Adams_2021 hasPollutant Adams_2021_CO
# Harris_2022_NO2 hasConcentration 19.77145317545748
# Los_Angeles_2023 hasPollutant Los_Angeles_2023_NO2
# Humboldt_2018_PM2.5 hasConcentration 7.590645161290322
# Fresno_2019_CO hasConcentration 0.4306930693069307
# Harris_2023 hasPopulation 4835125
# Contra_Costa_2019 hasCounty Contra_Costa
# Bexar_2019_NO2 hasConcentration 13.923361034164358
# Harrison_2019 hasCounty Harrison
# Los_Angeles_2019 hasPollutant Los_Angeles_2019_CO
# Los_Angeles_2018 hasPollutant Los_Angeles_2018_PM2.5
# Butte_2022_NO2 hasConcentration 11.768
# Travis_2022 hasCounty Travis
# Contra_Costa_2019 hasPollutant Contra_Costa_2019_PM2.5
# Fresno_2022 hasPollutant Fresno_2022_PM2.5
# Philadelphia_2023_CO hasConcentration 0.5020128087831657
# Bexar hasRUCC 1.0
# El_Paso_2023 hasMaxAQI 154.0
# Contra_Costa_2020_CO hasConcentration 0.5350684931506849
# Tarrant_2023 hasPopulation 2182947
# Cambria_2020 hasPollutant Cambria_2020_NO2
# Philadelphia_2023 hasCounty Philadelphia
# Cambria_2022 hasPopulation 131429
# Contra_Costa_2019_NO2 hasConcentration 12.65070323488045
# Bexar_2021 hasCounty Bexar
# Bexar_2020 hasCounty Bexar
# Harris_2020 hasCounty Harris
# Dallas_2022_PM2.5 hasConcentration 9.133928571428571
# Travis_2022 hasPollutant Travis_2022_CO
# Butte_2022 hasCounty Butte
# Philadelphia_2020 hasMaxAQI 119.0
# Lackawanna_2021 hasPollutant Lackawanna_2021_NO2
# Philadelphia_2021 hasPollutant Philadelphia_2021_PM2.5
# Allegheny_2021_NO2 hasConcentration 15.850071530758228
# Alameda_2019 hasPollutant Alameda_2019_CO
# Travis_2023 hasPopulation 1334961
# Bexar_2018_NO2 hasConcentration 13.018544366899302
# Imperial_2019_CO hasConcentration 0.4438356164383562
# Erie_2022 hasPollutant Erie_2022_CO
# Philadelphia_2018_CO hasConcentration 0.4784822286263209
# Cambria_2018 hasCounty Cambria
# Harrison_2021 hasMaxAQI 158.0
# Harris_2022 hasCounty Harris
# Dallas_2018 hasPollutant Dallas_2018_NO2
# Cambria_2022 hasPollutant Cambria_2022_CO
# Adams_2022 hasPopulation 105959
# Kern_2022_NO2 hasConcentration 24.12186459489456
# Erie_2022 hasPopulation 948423
# Harris_2018 hasMaxAQI 150.0
# Travis_2022_NO2 hasConcentration 16.470209059233447
# Contra_Costa_2022_PM2.5 hasConcentration 8.250305997552019
# Bexar_2022 hasPollutant Bexar_2022_NO2
# Fresno_2021 hasPollutant Fresno_2021_CO
# Harrison_2022 hasCounty Harrison
# Lackawanna_2022 hasMaxAQI 71.0
# Butte_2023 hasMaxAQI 87.0
# Kern_2022 hasPollutant Kern_2022_CO
# Travis_2023 hasPollutant Travis_2023_PM2.5
# Humboldt_2021_NO2 hasConcentration 4.506134969325154
# Dallas_2023 hasPopulation 2606358
# Lackawanna hasRUCC 2.0
# Pennsylvania hasState York
# Dallas_2018_PM2.5 hasConcentration 9.495042321644496
# Philadelphia_2020 hasPollutant Philadelphia_2020_NO2
# Tarrant_2021_PM2.5 hasConcentration 9.03142235123367
# Jefferson_2023 hasPollutant Jefferson_2023_NO2
# Jefferson_2018 hasPopulation 252655
# Monroe_2021 hasPopulation 755813
# Fresno_2019 hasCounty Fresno
# Monroe_2020 hasPollutant Monroe_2020_PM2.5
# California hasState Contra_Costa
# Tarrant_2020 hasPollutant Tarrant_2020_CO
# Humboldt_2022 hasMaxAQI 70.0
# Harrison_2020 hasMaxAQI 100.0
# Alameda_2021_CO hasConcentration 0.5091329479768786
# Jefferson_2020 hasPopulation 256133
# Kern_2020 hasPopulation 905910
# York_2021 hasPollutant York_2021_NO2
# Humboldt_2020 hasPopulation 136262
# Kern_2019 hasPopulation 898898
# Tarrant_2021 hasCounty Tarrant
# Erie_2020 hasPollutant Erie_2020_NO2
# Tarrant_2019_NO2 hasConcentration 17.991129643669446
# Travis_2018_NO2 hasConcentration 17.14613259668508
# Jefferson_2021 hasPollutant Jefferson_2021_NO2
# Cambria_2021 hasPollutant Cambria_2021_CO
# Cambria_2022_CO hasConcentration 0.4227146814404432
# Harrison_2018_PM2.5 hasConcentration 8.153233830845771
# Contra_Costa_2020 hasPollutant Contra_Costa_2020_PM2.5
# Cambria_2022 hasPollutant Cambria_2022_NO2
# Erie_2021_CO hasConcentration 0.287815750371471
# Contra_Costa_2021 hasPopulation 1163941
# Harris_2021 hasMaxAQI 179.0
# Tarrant_2019 hasPollutant Tarrant_2019_PM2.5
# Bexar_2018 hasCounty Bexar
# Travis_2019_CO hasConcentration 0.5008219178082192
# Dallas_2023_PM2.5 hasConcentration 10.12852969814995
# Lackawanna_2020 hasMaxAQI 81.0
# Imperial_2019 hasPollutant Imperial_2019_NO2
# Kern_2022 hasMaxAQI 289.0
# Kern_2019 hasPollutant Kern_2019_CO
# Travis_2021 hasCounty Travis
# Kern_2019 hasCounty Kern
# Los_Angeles_2020 hasPollutant Los_Angeles_2020_CO
# El_Paso_2022 hasPopulation 867239
# Alameda_2019 hasPollutant Alameda_2019_PM2.5
# Philadelphia_2018 hasCounty Philadelphia
# Pennsylvania hasState Allegheny
# York_2023_NO2 hasConcentration 19.51964809384164
# Contra_Costa_2023_PM2.5 hasConcentration 7.779856972586413
# Contra_Costa_2019 hasPollutant Contra_Costa_2019_NO2
# Kern_2021 hasPollutant Kern_2021_CO
# Lackawanna_2022 hasCounty Lackawanna
# Alameda_2023_PM2.5 hasConcentration 7.006504065040651
# Erie_2020_NO2 hasConcentration 17.05400641025641
# Allegheny_2018_PM2.5 hasConcentration 10.232767162066525
# Humboldt_2021 hasPopulation 134897
# Adams_2020 hasPollutant Adams_2020_CO
# Harris_2021 hasPopulation 4735517
# Adams_2019 hasMaxAQI 85.0
# Harrison_2023_NO2 hasConcentration 6.487577639751553
# York_2022 hasPopulation 461049
# Madera_2020_PM2.5 hasConcentration 17.067848101265824
# Adams_2019 hasPollutant Adams_2019_NO2
# Allegheny_2021 hasPollutant Allegheny_2021_NO2
# Tarrant_2018_NO2 hasConcentration 17.64032258064516
# Monroe_2020 hasPopulation 757551
# Alameda_2018 hasPollutant Alameda_2018_NO2
# Travis_2020 hasMaxAQI 153.0
# Humboldt_2020_PM2.5 hasConcentration 8.754716981132075
# Imperial_2021 hasCounty Imperial
# Harris_2023 hasPollutant Harris_2023_CO
# Lackawanna_2022_PM2.5 hasConcentration 7.199285714285714
# Tarrant_2022_NO2 hasConcentration 18.52365591397849
# Dallas_2018_CO hasConcentration 0.3045592705167173
# Contra_Costa_2020 hasMaxAQI 197.0
# Contra_Costa_2021 hasCounty Contra_Costa
# Humboldt_2019_NO2 hasConcentration 5.724
# Cambria_2023 hasPopulation 130668
# Philadelphia_2018 hasPollutant Philadelphia_2018_CO
# El_Paso_2019 hasPollutant El_Paso_2019_CO
# Bexar_2019 hasPopulation 2002445
# Dallas_2022 hasMaxAQI 148.0
# Erie_2020_CO hasConcentration 0.2809182209469154
# Bexar_2020 hasPollutant Bexar_2020_NO2
# Tarrant_2020_CO hasConcentration 0.4286885245901639
# Travis_2019_PM2.5 hasConcentration 8.58219557195572
# Los_Angeles_2018 hasPopulation 10061533
# Butte_2021 hasCounty Butte
# Lackawanna_2021 hasPollutant Lackawanna_2021_PM2.5
# Monroe_2018 hasPollutant Monroe_2018_CO
# Kern_2021 hasPollutant Kern_2021_PM2.5
# Monroe_2019 hasMaxAQI 90.0
# Adams_2023 hasCounty Adams
# Butte_2019 hasPollutant Butte_2019_NO2
# Lackawanna_2020 hasPollutant Lackawanna_2020_PM2.5
# Harrison_2022_PM2.5 hasConcentration 9.94775641025641
# Imperial_2018 hasPollutant Imperial_2018_NO2
# Lackawanna_2021_PM2.5 hasConcentration 7.460144927536231
# Humboldt_2022 hasPollutant Humboldt_2022_NO2
# Harris_2019_PM2.5 hasConcentration 8.952063066085206
# Imperial_2023_CO hasConcentration 0.4211267605633803
# Los_Angeles_2023_CO hasConcentration 0.4417693522906793
# Los_Angeles_2022 hasCounty Los_Angeles
# Jefferson_2022 hasPopulation 251601
# Tarrant_2022 hasMaxAQI 172.0
# Imperial_2023_PM2.5 hasConcentration 8.818009478672986
# Cambria_2019 hasPollutant Cambria_2019_PM2.5
# Cambria_2018 hasPollutant Cambria_2018_PM2.5
# Contra_Costa_2018 hasPopulation 1150840
# Harrison_2023 hasCounty Harrison
# Humboldt_2020 hasPollutant Humboldt_2020_NO2
# New_York hasState Monroe
# Los_Angeles_2020_PM2.5 hasConcentration 13.495547690014904
# Humboldt_2018_NO2 hasConcentration 4.431055900621118
# Butte_2019 hasPopulation 218726
# Pennsylvania hasState Adams
# Alameda_2018_PM2.5 hasConcentration 12.913035019455254
# El_Paso_2021 hasCounty El_Paso
# Cambria_2022_PM2.5 hasConcentration 9.50933147632312
# Monroe_2022_CO hasConcentration 0.2814447592067988
# Contra_Costa_2022_NO2 hasConcentration 12.343021582733812
# Harris_2023_PM2.5 hasConcentration 10.811313179026923
# Adams_2019 hasPollutant Adams_2019_CO
# Bexar_2022 hasMaxAQI 194.0
# Harris_2018_NO2 hasConcentration 18.54307897071872
# Jefferson_2022 hasMaxAQI 129.0
# Contra_Costa_2023 hasPollutant Contra_Costa_2023_CO
# York_2022 hasPollutant York_2022_PM2.5
# Lackawanna_2018_CO hasConcentration 0.3668493150684931
# Philadelphia_2019_NO2 hasConcentration 24.066425120772948
# Bexar_2021 hasMaxAQI 147.0
# Cambria_2018_NO2 hasConcentration 13.12391930835735
# Humboldt_2018 hasPollutant Humboldt_2018_PM2.5
# Erie_2020 hasPollutant Erie_2020_CO
# Travis_2022_CO hasConcentration 0.5632302405498282
# Humboldt_2022 hasPollutant Humboldt_2022_PM2.5
# Imperial_2021 hasPollutant Imperial_2021_NO2
# Contra_Costa_2022 hasMaxAQI 129.0
# Harris_2018 hasPollutant Harris_2018_NO2
# Tarrant_2018 hasPollutant Tarrant_2018_NO2
# Erie_2020 hasPopulation 952342
# Tarrant_2018 hasPopulation 2080998
# York_2022 hasMaxAQI 105.0
# Tarrant_2019_CO hasConcentration 0.4642659279778393
# Bexar_2023 hasCounty Bexar
# Alameda_2023 hasPollutant Alameda_2023_CO
# Kern_2018 hasCounty Kern
# Madera_2018 hasPopulation 156373
# Travis_2022 hasMaxAQI 129.0
# Butte_2021 hasPopulation 206336
# Kern_2021 hasPollutant Kern_2021_NO2
# Monroe_2023 hasPollutant Monroe_2023_CO
# Allegheny_2023 hasPopulation 1224825
# Cambria_2018_CO hasConcentration 0.1741046831955923
# Lackawanna_2018 hasPollutant Lackawanna_2018_NO2
# El_Paso_2022_CO hasConcentration 0.3200589970501475
# Humboldt_2022_NO2 hasConcentration 5.170030581039755
# Adams_2023_NO2 hasConcentration 4.461690140845071
# Allegheny_2018 hasPollutant Allegheny_2018_CO
# Allegheny_2020 hasMaxAQI 128.0
# Allegheny_2023 hasPollutant Allegheny_2023_CO
# Bexar_2023 hasMaxAQI 279.0
# Tarrant_2019_PM2.5 hasConcentration 8.783619817997979
# Butte_2020_PM2.5 hasConcentration 13.476045627376426
# Dallas_2018 hasCounty Dallas
# Kern_2020 hasMaxAQI 267.0
# Kern_2018 hasMaxAQI 150.0
# Travis_2019 hasCounty Travis
# Contra_Costa_2020_PM2.5 hasConcentration 11.085572139303482
# Harris_2023_CO hasConcentration 0.4462335216572504
# Adams_2023 hasPollutant Adams_2023_PM2.5
# Adams_2019 hasPollutant Adams_2019_PM2.5
# Dallas_2021 hasPollutant Dallas_2021_PM2.5
# Harris_2023 hasMaxAQI 205.0
# Texas hasState Harrison
# Tarrant_2020 hasPollutant Tarrant_2020_PM2.5
# Butte_2023_PM2.5 hasConcentration 7.604283216783216
# Allegheny_2018_NO2 hasConcentration 16.603081232492997
# El_Paso_2019 hasPopulation 837501
# Fresno_2023 hasCounty Fresno
# Harrison_2020_PM2.5 hasConcentration 7.814180929095355
# Erie_2022_CO hasConcentration 0.2842475386779184
# El_Paso_2019 hasPollutant El_Paso_2019_PM2.5
# Imperial_2022 hasPollutant Imperial_2022_CO
# Harris_2023_NO2 hasConcentration 19.87638768430182
# Alameda_2019_CO hasConcentration 0.55
# Los_Angeles_2023 hasPollutant Los_Angeles_2023_PM2.5
# Imperial_2022_NO2 hasConcentration 21.49462989840348
# Madera_2021 hasMaxAQI 194.0
# Butte_2019 hasPollutant Butte_2019_CO
# Tarrant_2020_PM2.5 hasConcentration 8.828057553956835
# Pennsylvania hasState Cambria
# Humboldt_2018 hasMaxAQI 150.0
# Adams_2021 hasPopulation 105686
# Humboldt_2018 hasPollutant Humboldt_2018_NO2
# Harris_2022 hasPollutant Harris_2022_PM2.5
# Jefferson_2019 hasMaxAQI 150.0
# Harrison_2019_PM2.5 hasConcentration 7.869402985074627
# Harrison_2023 hasPollutant Harrison_2023_NO2
# Cambria_2023 hasCounty Cambria
# York_2019 hasPollutant York_2019_NO2
# Tarrant_2021 hasPollutant Tarrant_2021_PM2.5
# Jefferson_2023_NO2 hasConcentration 11.353240279162511
# Alameda_2020 hasMaxAQI 218.0
# Jefferson_2022 hasPollutant Jefferson_2022_NO2
# El_Paso_2021 hasPollutant El_Paso_2021_NO2
# Harrison_2020 hasCounty Harrison
# Travis_2021_NO2 hasConcentration 16.23140028288543
# Los_Angeles_2021 hasMaxAQI 281.0
# Fresno_2021 hasCounty Fresno
# Tarrant_2022 hasPollutant Tarrant_2022_PM2.5
# Allegheny_2018 hasPopulation 1217508
# Fresno_2018 hasMaxAQI 150.0
# Contra_Costa_2018 hasPollutant Contra_Costa_2018_CO
# Philadelphia_2019 hasCounty Philadelphia
# Allegheny_2023_CO hasConcentration 0.6318721461187214
# Lackawanna_2020 hasPopulation 215539
# Madera_2018 hasPollutant Madera_2018_NO2
# Humboldt_2022_CO hasConcentration 0.2457534246575342
# Humboldt_2023 hasMaxAQI 274.0
# Tarrant_2018 hasCounty Tarrant
# Adams_2021 hasPollutant Adams_2021_PM2.5
# Kern_2020_NO2 hasConcentration 21.819986168741355
# Cambria_2023_NO2 hasConcentration 12.730337078651685
# Allegheny_2022 hasPollutant Allegheny_2022_NO2
# Madera_2021_PM2.5 hasConcentration 12.398879551820729
# Butte_2023 hasPollutant Butte_2023_CO
# Harris_2021_PM2.5 hasConcentration 9.901345816266824
# Fresno_2019_NO2 hasConcentration 20.022569444444443
# York_2021 hasPollutant York_2021_PM2.5
# Imperial_2019 hasCounty Imperial
# Monroe_2023_CO hasConcentration 0.31321044546851
# Tarrant_2020_NO2 hasConcentration 16.19875419262099
# Harris_2021_CO hasConcentration 0.4652214891611687
# Monroe_2023 hasPopulation 748482
# Dallas_2018 hasPollutant Dallas_2018_PM2.5
# Butte_2022 hasPollutant Butte_2022_CO
# Dallas_2023 hasMaxAQI 172.0
# El_Paso_2019_NO2 hasConcentration 26.79536354056902
# Dallas_2018 hasMaxAQI 150.0
# Monroe hasRUCC 1.0
# Imperial_2023 hasPollutant Imperial_2023_NO2
# Madera_2022 hasCounty Madera
# Allegheny_2022 hasCounty Allegheny
# Allegheny_2022_CO hasConcentration 0.529537037037037
# Dallas_2022 hasPollutant Dallas_2022_NO2
# Allegheny_2021 hasPollutant Allegheny_2021_PM2.5
# York_2020 hasMaxAQI 97.0
# Adams_2023_CO hasConcentration 0.2011204481792717
# Erie_2023 hasMaxAQI 169.0
# Lackawanna_2023_PM2.5 hasConcentration 10.184375
# Allegheny_2021_CO hasConcentration 0.5787114845938375
# El_Paso_2023 hasPollutant El_Paso_2023_CO
# Alameda_2022 hasPollutant Alameda_2022_PM2.5
# Allegheny_2019 hasPopulation 1215716
# Philadelphia_2018 hasPollutant Philadelphia_2018_PM2.5
# Bexar_2022 hasPollutant Bexar_2022_PM2.5
# El_Paso_2020_CO hasConcentration 0.3546184738955823
# Humboldt_2023_CO hasConcentration 0.3147368421052632
# Alameda_2019 hasPollutant Alameda_2019_NO2
# Dallas_2018_NO2 hasConcentration 17.3457761732852
# Alameda_2021 hasPollutant Alameda_2021_NO2
# Philadelphia_2022_NO2 hasConcentration 24.32075471698113
# Lackawanna_2022_CO hasConcentration 0.3961325966850829
# Los_Angeles_2023 hasPollutant Los_Angeles_2023_CO
# Fresno_2019 hasPollutant Fresno_2019_CO
# Philadelphia_2022 hasPollutant Philadelphia_2022_NO2
# Harrison_2022 hasPopulation 70038
# Los_Angeles_2019_CO hasConcentration 0.4752320065992988
# York_2019_NO2 hasConcentration 18.91111111111111
# Contra_Costa_2019_CO hasConcentration 0.4132596685082873
# Philadelphia_2021 hasPollutant Philadelphia_2021_NO2
# Allegheny_2021 hasMaxAQI 153.0
# Dallas_2019 hasPopulation 2635603
# Imperial_2019_PM2.5 hasConcentration 9.570178926441352
# Cambria_2019_PM2.5 hasConcentration 9.025586854460094
# El_Paso_2021 hasPollutant El_Paso_2021_CO
# Harris_2023 hasPollutant Harris_2023_NO2
# Tarrant_2023_NO2 hasConcentration 18.78756027000964
# Allegheny_2023_PM2.5 hasConcentration 10.879970363052603
# Travis_2020_NO2 hasConcentration 20.461746361746364
# Humboldt_2023 hasPollutant Humboldt_2023_PM2.5
# York_2018 hasPopulation 448417
# Contra_Costa_2018_CO hasConcentration 0.428310502283105
# Allegheny_2023 hasCounty Allegheny
# Bexar_2022_CO hasConcentration 0.3178082191780822
# Los_Angeles_2022_CO hasConcentration 0.4727993206906312
# Los_Angeles_2022 hasMaxAQI 209.0
# Contra_Costa_2021 hasPollutant Contra_Costa_2021_PM2.5
# Philadelphia_2021_NO2 hasConcentration 24.003075489282384
# Allegheny_2018 hasPollutant Allegheny_2018_PM2.5
# Monroe_2022 hasCounty Monroe
# Travis_2020 hasPollutant Travis_2020_CO
# Harris_2019_NO2 hasConcentration 19.42024096385542
# El_Paso_2020 hasPollutant El_Paso_2020_PM2.5
# Bexar_2021_CO hasConcentration 0.2048295454545454
# Alameda_2023 hasMaxAQI 104.0
# Los_Angeles_2021 hasPopulation 9809462
# Cambria_2018 hasPollutant Cambria_2018_NO2
# Lackawanna_2021_CO hasConcentration 0.2468208092485549
# Cambria_2021 hasCounty Cambria
# Jefferson_2020 hasPollutant Jefferson_2020_NO2
# Madera_2020 hasPollutant Madera_2020_PM2.5
# Los_Angeles_2019_PM2.5 hasConcentration 10.186762911752744
# Tarrant_2018_CO hasConcentration 0.4706849315068493
# Harris_2018 hasPollutant Harris_2018_CO
# Harrison_2019 hasPopulation 66484
# Butte_2019_PM2.5 hasConcentration 6.970972886762361
# Philadelphia_2022 hasMaxAQI 113.0
# Fresno_2019 hasMaxAQI 187.0
# Harrison_2018_NO2 hasConcentration 5.358379888268156
# Adams_2022 hasPollutant Adams_2022_PM2.5
# Humboldt_2021 hasMaxAQI 60.0
# Harris_2021 hasCounty Harris
# Cambria_2021_PM2.5 hasConcentration 9.56257142857143
# Fresno_2019 hasPopulation 997847
# Harris_2019 hasPopulation 4709243
# Philadelphia_2022 hasPopulation 1566836
# Harris_2021 hasPollutant Harris_2021_PM2.5
# Harris_2022 hasPollutant Harris_2022_CO
# Cambria_2019 hasCounty Cambria
# Lackawanna_2020 hasPollutant Lackawanna_2020_CO
# Los_Angeles_2019 hasCounty Los_Angeles
# Madera_2021 hasCounty Madera
# Kern_2018_CO hasConcentration 0.2912195121951219
# Lackawanna_2019 hasPopulation 209808
# Butte_2018 hasMaxAQI 150.0
# Contra_Costa_2022 hasPollutant Contra_Costa_2022_CO
# Fresno_2018 hasPopulation 991298
# Fresno_2021 hasPollutant Fresno_2021_PM2.5
# Adams_2021_CO hasConcentration 0.142152466367713
# Travis_2022 hasPollutant Travis_2022_NO2
# Fresno_2023 hasPollutant Fresno_2023_NO2
# Philadelphia_2022_PM2.5 hasConcentration 8.222641129032258
# Bexar_2020_NO2 hasConcentration 11.148268398268398
# Travis_2023 hasCounty Travis
# Monroe_2022 hasPopulation 750887
# York_2018_PM2.5 hasConcentration 9.645555555555555
# Tarrant_2019 hasCounty Tarrant
# Monroe_2019 hasPollutant Monroe_2019_CO
# Contra_Costa_2021_NO2 hasConcentration 10.994034090909093
# Dallas_2021_PM2.5 hasConcentration 8.346026490066226
# Travis_2022 hasPollutant Travis_2022_PM2.5
# Travis_2022_PM2.5 hasConcentration 8.676617375231054
# El_Paso_2022 hasPollutant El_Paso_2022_PM2.5
# Cambria_2023_CO hasConcentration 0.3415977961432507
# El_Paso_2019_PM2.5 hasConcentration 8.460144451739986
# Harris_2018 hasPollutant Harris_2018_PM2.5
# Fresno_2020_PM2.5 hasConcentration 16.79508970727101
# Allegheny_2019 hasPollutant Allegheny_2019_NO2
# Adams_2020_CO hasConcentration 0.0620218579234972
# Contra_Costa_2020_NO2 hasConcentration 12.39246861924686
# Fresno_2018_NO2 hasConcentration 21.866462264150943
# Lackawanna_2023 hasPopulation 216123
# Humboldt_2018 hasPollutant Humboldt_2018_CO
# Philadelphia_2022 hasPollutant Philadelphia_2022_CO
# Jefferson_2019 hasPollutant Jefferson_2019_PM2.5
# Harris_2018 hasPopulation 4676913
# Lackawanna_2018_PM2.5 hasConcentration 8.286842105263156
# Butte_2023 hasPollutant Butte_2023_PM2.5
# Jefferson_2019_NO2 hasConcentration 10.229690522243711
# Dallas_2019 hasPollutant Dallas_2019_CO
# Philadelphia_2021_PM2.5 hasConcentration 9.404932537049325
# Jefferson_2023 hasMaxAQI 122.0
# Travis_2019 hasPopulation 1273567
# Dallas_2022_CO hasConcentration 0.2733516483516483
# Madera_2019_NO2 hasConcentration 12.476685393258428
# Contra_Costa_2019_PM2.5 hasConcentration 7.175215782983971
# El_Paso_2022_PM2.5 hasConcentration 9.37390180878553
# Adams_2020 hasMaxAQI 86.0
# Kern_2021 hasMaxAQI 316.0
# York_2022 hasCounty York
# Imperial_2021 hasMaxAQI 442.0
# Harris_2023 hasCounty Harris
# Lackawanna_2019 hasPollutant Lackawanna_2019_CO
# Kern_2018 hasPollutant Kern_2018_NO2
# Bexar_2023_PM2.5 hasConcentration 8.998339100346021
# Kern_2023_CO hasConcentration 0.3286908077994429
# El_Paso_2021_CO hasConcentration 0.3350894632206759
# Imperial_2022 hasPollutant Imperial_2022_PM2.5
# Monroe_2023 hasCounty Monroe
# Allegheny_2023 hasPollutant Allegheny_2023_NO2
# Imperial_2020 hasCounty Imperial
# El_Paso_2020 hasMaxAQI 192.0
# Kern_2021_NO2 hasConcentration 24.0256976744186
# Harris_2022 hasPollutant Harris_2022_NO2
# Jefferson_2019 hasPollutant Jefferson_2019_NO2
# Jefferson_2022 hasCounty Jefferson
# Butte_2022_CO hasConcentration 0.3290055248618784
# Humboldt_2021_CO hasConcentration 0.2729166666666667
# Allegheny_2020 hasPopulation 1249565
# Tarrant_2019 hasPopulation 2101282
# Lackawanna_2023_NO2 hasConcentration 24.376190476190477
# Jefferson_2021 hasCounty Jefferson
# Butte_2022 hasPollutant Butte_2022_PM2.5
# Madera_2022_NO2 hasConcentration 12.461944444444445
# El_Paso_2020 hasPollutant El_Paso_2020_CO
# Dallas_2019 hasCounty Dallas
# Adams_2023 hasMaxAQI 216.0
# Butte_2020_NO2 hasConcentration 12.346111111111112
# Fresno_2020_NO2 hasConcentration 20.78995716325559
# Madera_2020 hasPollutant Madera_2020_NO2
# Butte hasRUCC 3.0
# Adams_2020_PM2.5 hasConcentration 7.342909090909091
# Cambria_2019_NO2 hasConcentration 14.506172839506172
# Cambria_2020 hasPollutant Cambria_2020_PM2.5
# El_Paso_2018 hasPollutant El_Paso_2018_CO
# York_2021_NO2 hasConcentration 19.30952380952381
# Cambria_2023 hasPollutant Cambria_2023_NO2
# Imperial_2020 hasPopulation 179612
# Fresno_2020 hasPollutant Fresno_2020_PM2.5
# Tarrant_2022 hasPollutant Tarrant_2022_NO2
# Dallas_2019_CO hasConcentration 0.273463687150838
# Dallas_2023 hasCounty Dallas
# Travis_2021 hasMaxAQI 101.0
# Imperial_2021_NO2 hasConcentration 20.26813655761024
# Humboldt_2018 hasPopulation 136502
# Tarrant_2023_CO hasConcentration 0.4737142857142857
# Contra_Costa_2018_NO2 hasConcentration 13.163425253991292
# Monroe_2018 hasPopulation 744239
# Los_Angeles_2022 hasPollutant Los_Angeles_2022_PM2.5
# Contra_Costa_2020 hasPopulation 1166069
# Madera_2020 hasPopulation 156345
# Bexar_2021 hasPollutant Bexar_2021_PM2.5
# Adams_2019_CO hasConcentration 0.1391061452513966
# Harris hasRUCC 1.0
# Erie_2020 hasMaxAQI 155.0
# Imperial_2021 hasPollutant Imperial_2021_CO
# Texas hasState Harris
# Allegheny_2020_PM2.5 hasConcentration 8.842998897464167
# El_Paso_2023_PM2.5 hasConcentration 10.251533219761498
# Butte_2023 hasPopulation 207172
# Humboldt_2023 hasPollutant Humboldt_2023_CO
# Los_Angeles_2018_PM2.5 hasConcentration 12.26665268456376
# Butte_2019 hasPollutant Butte_2019_PM2.5
# Alameda_2020_NO2 hasConcentration 20.980055274067247
# Dallas_2018 hasPopulation 2629764
# Bexar_2023_NO2 hasConcentration 11.859278350515464
# Fresno_2023 hasPopulation 1017162
# Harrison_2020 hasPollutant Harrison_2020_NO2
# York_2021 hasPopulation 459183
# Allegheny_2019_CO hasConcentration 0.5065740740740741
# Los_Angeles_2020_CO hasConcentration 0.4955687830687831
# Monroe_2020_PM2.5 hasConcentration 6.088013411567477
# Kern_2018_NO2 hasConcentration 23.067616959064328
# Imperial_2021 hasPopulation 179138
# Jefferson_2022 hasPollutant Jefferson_2022_PM2.5
# Allegheny_2022 hasPollutant Allegheny_2022_PM2.5
# Travis_2019 hasPollutant Travis_2019_NO2
# York_2023 hasPopulation 464640
# Lackawanna_2023 hasPollutant Lackawanna_2023_CO
# Jefferson_2021 hasPollutant Jefferson_2021_PM2.5
# California hasState Los_Angeles
# Bexar_2022 hasPopulation 2060191
# York_2018 hasPollutant York_2018_PM2.5
# Harris_2022 hasMaxAQI 179.0
# Allegheny_2020 hasPollutant Allegheny_2020_PM2.5
# Tarrant_2022_CO hasConcentration 0.4420329670329671
# Bexar_2022_NO2 hasConcentration 11.61350507416081
# Butte_2018 hasPollutant Butte_2018_PM2.5
# Los_Angeles_2021 hasCounty Los_Angeles
# Bexar_2018 hasPollutant Bexar_2018_NO2
# Alameda_2020_CO hasConcentration 0.5883835616438355
# Alameda_2021 hasPollutant Alameda_2021_CO
# Butte_2021_CO hasConcentration 0.3151603498542273
# Imperial_2019_NO2 hasConcentration 20.959049360146253
# Erie_2023 hasCounty Erie
# Alameda_2020 hasPopulation 1680466
# New_York hasState Erie
# Madera_2023 hasCounty Madera
# Alameda_2022_NO2 hasConcentration 19.507897664071187
# Adams_2018_NO2 hasConcentration 2.939068100358423
# Imperial_2020_CO hasConcentration 0.5295857988165681
# Humboldt_2019 hasPopulation 135839
# Contra_Costa_2018 hasPollutant Contra_Costa_2018_NO2
# Butte_2018 hasPopulation 230330
# York_2023 hasPollutant York_2023_PM2.5
# Los_Angeles_2022 hasPollutant Los_Angeles_2022_NO2
# Bexar_2023 hasPopulation 2087679
# Jefferson hasRUCC 2.0
# Bexar_2019 hasPollutant Bexar_2019_NO2
# Kern_2022 hasPollutant Kern_2022_NO2
# Madera_2021 hasPopulation 158966
# Alameda_2021_PM2.5 hasConcentration 8.437020863658418
# Harris_2019 hasMaxAQI 202.0
# Cambria_2018_PM2.5 hasConcentration 8.441040462427745
# Cambria_2019_CO hasConcentration 0.1635616438356164
# Dallas_2022 hasPopulation 2601993
# Kern_2021 hasCounty Kern
# Lackawanna_2019 hasPollutant Lackawanna_2019_NO2
# York_2021 hasMaxAQI 148.0
# Travis_2018_CO hasConcentration 0.4684931506849315
# Bexar_2023_CO hasConcentration 0.3536986301369862
# Cambria_2018 hasMaxAQI 150.0
# Humboldt_2023_NO2 hasConcentration 4.522287390029326
# Contra_Costa_2022 hasCounty Contra_Costa
# York_2022_PM2.5 hasConcentration 8.44112676056338
# Philadelphia_2023 hasMaxAQI 290.0
# Allegheny_2023 hasMaxAQI 212.0
# Kern_2023 hasPollutant Kern_2023_CO
# Adams_2022_NO2 hasConcentration 5.046067415730337
# York_2023 hasCounty York
# Harris_2021_NO2 hasConcentration 18.63961830305817
# Texas hasState Tarrant
# York_2023_PM2.5 hasConcentration 11.435984095427436
# Butte_2021 hasPollutant Butte_2021_PM2.5
# Cambria_2020 hasPollutant Cambria_2020_CO
# Imperial_2022 hasMaxAQI 762.0
# Harris_2020 hasPollutant Harris_2020_NO2
# Fresno_2018_CO hasConcentration 0.3794990723562152
# Dallas_2022_NO2 hasConcentration 18.67133443163097
# Contra_Costa_2018 hasPollutant Contra_Costa_2018_PM2.5
# Madera_2018_PM2.5 hasConcentration 14.116042780748662
# Fresno_2022_PM2.5 hasConcentration 10.188663527707352
# Philadelphia_2021 hasCounty Philadelphia
# Harrison_2021 hasCounty Harrison
# Erie_2018 hasPopulation 919941
# Fresno_2019_PM2.5 hasConcentration 8.502508423811307
# Kern_2018 hasPollutant Kern_2018_CO
# Jefferson_2019 hasCounty Jefferson
# Humboldt_2019 hasPollutant Humboldt_2019_NO2
# Contra_Costa_2021_CO hasConcentration 0.4312730627306273
# Contra_Costa_2018 hasMaxAQI 150.0
# Los_Angeles_2021 hasPollutant Los_Angeles_2021_NO2
# Butte_2020_CO hasConcentration 0.4031609195402299
# Kern_2023 hasPollutant Kern_2023_PM2.5
# Alameda_2020_PM2.5 hasConcentration 10.967345993515517
# Adams_2023 hasPopulation 106748
# Alameda_2021 hasPopulation 1644047
# Lackawanna_2020 hasPollutant Lackawanna_2020_NO2
# El_Paso_2020 hasPopulation 866606
# Harris_2020_NO2 hasConcentration 17.861147612790187
# Kern_2021_PM2.5 hasConcentration 12.379547395388558
# Bexar_2021 hasPopulation 2030981
# Monroe_2019 hasPopulation 742605
# El_Paso_2023_NO2 hasConcentration 33.21738437001595
# Contra_Costa_2021_PM2.5 hasConcentration 8.3681652490887
# Los_Angeles_2023 hasPopulation 9663345
# Dallas_2023_CO hasConcentration 0.3024657534246575
# Kern_2019_NO2 hasConcentration 23.879849012775843
# Fresno_2023 hasPollutant Fresno_2023_PM2.5
# Philadelphia_2023 hasPopulation 1550542
# Monroe_2018_CO hasConcentration 0.3110650069156293
# Monroe_2021_CO hasConcentration 0.2905292479108635
# Allegheny_2021 hasPopulation 1245220
# Erie_2020_PM2.5 hasConcentration 6.487407407407408
# Dallas_2021_NO2 hasConcentration 17.879453189726593
# Madera_2021 hasPollutant Madera_2021_PM2.5
# York_2022_NO2 hasConcentration 19.30819209039548
# Lackawanna_2021 hasPopulation 216043
# Kern_2022 hasCounty Kern
# Dallas_2023 hasPollutant Dallas_2023_CO
# Jefferson_2020_PM2.5 hasConcentration 8.126086956521739
# Dallas_2020 hasPollutant Dallas_2020_CO
# Tarrant_2023 hasPollutant Tarrant_2023_PM2.5
# Bexar_2018 hasPollutant Bexar_2018_PM2.5
# Lackawanna_2019 hasPollutant Lackawanna_2019_PM2.5
# Bexar_2019_PM2.5 hasConcentration 9.161132922041505
# Philadelphia_2019 hasPollutant Philadelphia_2019_PM2.5
# Fresno hasRUCC 1.0
# Harrison_2021 hasPollutant Harrison_2021_PM2.5
# Harrison_2021_NO2 hasConcentration 5.9025352112676055
# Butte_2022 hasMaxAQI 119.0
# Erie_2020 hasCounty Erie
# Erie_2021 hasPopulation 952912
# Adams_2019 hasCounty Adams
# Harris_2022_PM2.5 hasConcentration 9.97072924552107
# Butte_2021 hasPollutant Butte_2021_CO
# Harrison_2019_NO2 hasConcentration 6.57090395480226
# Contra_Costa_2023_NO2 hasConcentration 10.25640287769784
# Travis_2018 hasPollutant Travis_2018_PM2.5
# Adams_2023 hasPollutant Adams_2023_CO
# El_Paso_2023 hasCounty El_Paso
# Erie_2021 hasCounty Erie
# El_Paso_2019 hasCounty El_Paso
# Butte_2023_NO2 hasConcentration 11.654407294832827
# Imperial_2022_PM2.5 hasConcentration 9.552307692307693
# Tarrant_2020 hasPollutant Tarrant_2020_NO2
# Erie_2023_CO hasConcentration 0.3146978021978022
# York_2019 hasMaxAQI 93.0
# Butte_2020 hasMaxAQI 379.0
# York_2019 hasPollutant York_2019_PM2.5
# Kern_2021_CO hasConcentration 0.4016438356164383
# Tarrant_2018 hasPollutant Tarrant_2018_CO
# Tarrant_2021 hasMaxAQI 209.0
# Harris_2018 hasCounty Harris
# Adams_2022_CO hasConcentration 0.1512534818941504
# Contra_Costa_2018_PM2.5 hasConcentration 13.12025495750708
# Allegheny_2019_NO2 hasConcentration 16.47354570637119
# York_2020 hasPollutant York_2020_NO2
# Allegheny_2018 hasCounty Allegheny
# Madera_2018_NO2 hasConcentration 12.641225626740946
# Allegheny_2022 hasPopulation 1232605
# Madera_2023 hasPopulation 162858
# Cambria_2020 hasCounty Cambria
# Monroe_2020 hasCounty Monroe
# Adams_2018_PM2.5 hasConcentration 8.035353535353535
# Erie_2019_CO hasConcentration 0.303013698630137
# Travis_2023 hasMaxAQI 122.0
# Madera_2023_NO2 hasConcentration 10.910584958217273
# Humboldt_2023 hasCounty Humboldt
# Travis_2020 hasPollutant Travis_2020_PM2.5
# Tarrant_2023_PM2.5 hasConcentration 10.228328402366865
# Bexar_2023 hasPollutant Bexar_2023_NO2
# Dallas_2021 hasPollutant Dallas_2021_CO
# Lackawanna_2019 hasCounty Lackawanna
# Fresno_2020 hasMaxAQI 298.0
# Fresno_2019 hasPollutant Fresno_2019_NO2
# Madera_2018 hasCounty Madera
# Erie_2018_CO hasConcentration 0.2887362637362637
# Kern_2022_PM2.5 hasConcentration 9.882254607801114
# Philadelphia_2018 hasMaxAQI 150.0
# Lackawanna_2020_NO2 hasConcentration 23.08333333333333
# Los_Angeles_2018 hasMaxAQI 150.0
# Lackawanna_2019_NO2 hasConcentration 22.713872832369944
# Adams_2021 hasMaxAQI 129.0
# Dallas_2022 hasPollutant Dallas_2022_CO
# Imperial_2018 hasCounty Imperial
# Imperial_2018 hasPollutant Imperial_2018_CO
# Los_Angeles_2020 hasPollutant Los_Angeles_2020_PM2.5
# El_Paso_2020_PM2.5 hasConcentration 8.705886036318097
# Harris_2022 hasPopulation 4781337
# Adams_2022 hasMaxAQI 97.0
# Philadelphia_2023 hasPollutant Philadelphia_2023_CO
# Philadelphia_2022_CO hasConcentration 0.4809833024118738
# El_Paso_2021 hasMaxAQI 150.0
# Adams_2021_NO2 hasConcentration 4.094462540716612
# Harris_2019 hasPollutant Harris_2019_CO
# Butte_2019_CO hasConcentration 0.3159779614325069
# Alameda_2018 hasPollutant Alameda_2018_PM2.5
# Alameda_2020 hasPollutant Alameda_2020_NO2
# Butte_2019_NO2 hasConcentration 14.428366762177651
# Butte_2021 hasPollutant Butte_2021_NO2
# El_Paso_2019_CO hasConcentration 0.4148221343873517
# Monroe_2018 hasMaxAQI 150.0
# Butte_2020 hasPollutant Butte_2020_NO2
# York_2019 hasCounty York
# Bexar_2020 hasPollutant Bexar_2020_PM2.5
# California hasState Humboldt
# Adams_2018 hasPollutant Adams_2018_PM2.5
# Imperial_2018 hasMaxAQI 150.0
# Los_Angeles_2020 hasCounty Los_Angeles
# Butte_2023_CO hasConcentration 0.3124242424242424
# Cambria_2021 hasPollutant Cambria_2021_NO2
# El_Paso_2018_NO2 hasConcentration 31.235653235653235
# Monroe_2020_NO2 hasConcentration 12.578547854785478
# Butte_2018_NO2 hasConcentration 15.17673130193906
# Cambria_2020 hasMaxAQI 89.0
# Bexar_2019 hasCounty Bexar
# Harrison_2022 hasPollutant Harrison_2022_NO2
# Lackawanna_2023 hasPollutant Lackawanna_2023_PM2.5
# Imperial_2020 hasPollutant Imperial_2020_CO
# Jefferson_2021 hasPopulation 253727
# Jefferson_2020 hasPollutant Jefferson_2020_PM2.5
# Alameda_2021 hasCounty Alameda
# Philadelphia_2021 hasPopulation 1589623
# Allegheny_2018_CO hasConcentration 0.4770949720670391
# Erie_2023 hasPollutant Erie_2023_CO
# Dallas_2020 hasPopulation 2610112
# El_Paso_2020 hasPollutant El_Paso_2020_NO2
# Humboldt_2019 hasPollutant Humboldt_2019_CO
# York_2020 hasCounty York
# Cambria_2022 hasPollutant Cambria_2022_PM2.5
# Philadelphia_2023_NO2 hasConcentration 24.579564806054872
# Los_Angeles_2022_PM2.5 hasConcentration 10.971637080867849
# Harris_2020 hasPollutant Harris_2020_PM2.5
# Humboldt_2020_CO hasConcentration 0.3435754189944134
# Cambria_2019 hasPollutant Cambria_2019_NO2
# Fresno_2021 hasPopulation 1013103
# Tarrant_2022_PM2.5 hasConcentration 8.80228734810579
# Kern hasRUCC 2.0
# Allegheny_2020_NO2 hasConcentration 15.45695652173913
# Madera_2021_NO2 hasConcentration 11.916759776536312
# Tarrant_2021 hasPollutant Tarrant_2021_CO
# Kern_2019 hasPollutant Kern_2019_NO2
# Los_Angeles_2020 hasMaxAQI 235.0
# Imperial_2020 hasPollutant Imperial_2020_NO2
# Dallas_2021 hasCounty Dallas
# Madera_2019 hasPollutant Madera_2019_NO2
# Travis_2021 hasPollutant Travis_2021_NO2
# Jefferson_2018 hasPollutant Jefferson_2018_CO
# El_Paso_2022 hasPollutant El_Paso_2022_CO
# Cambria_2023_PM2.5 hasConcentration 9.494350282485875
# Fresno_2021 hasPollutant Fresno_2021_NO2
# Contra_Costa_2019 hasPollutant Contra_Costa_2019_CO
# Bexar_2020 hasMaxAQI 158.0
# Humboldt_2022 hasPollutant Humboldt_2022_CO
# Philadelphia_2020_NO2 hasConcentration 22.837047353760447
# Kern_2019_PM2.5 hasConcentration 8.333493282149712
# Imperial_2023 hasPollutant Imperial_2023_PM2.5
# Pennsylvania hasState Lackawanna
# Adams_2021 hasCounty Adams
# Jefferson_2019_PM2.5 hasConcentration 8.4
# Imperial_2020 hasMaxAQI 166.0
# Alameda_2023 hasPollutant Alameda_2023_PM2.5
# Philadelphia_2019 hasPollutant Philadelphia_2019_CO
# Imperial hasRUCC 3.0
# Fresno_2023_PM2.5 hasConcentration 8.944411872480762
# Los_Angeles_2023_PM2.5 hasConcentration 10.078864809081526
# Humboldt_2021 hasPollutant Humboldt_2021_PM2.5
# Tarrant_2022 hasPollutant Tarrant_2022_CO
# Harrison_2018 hasCounty Harrison
# Madera_2022 hasMaxAQI 136.0
# Philadelphia_2020 hasPopulation 1600684
# Travis_2021 hasPollutant Travis_2021_PM2.5
# Adams_2020_NO2 hasConcentration 3.776504297994269
# Contra_Costa_2018 hasCounty Contra_Costa
# Bexar_2018 hasMaxAQI 150.0
# Butte_2018 hasPollutant Butte_2018_CO
# Dallas_2019 hasPollutant Dallas_2019_NO2
# Fresno_2021_NO2 hasConcentration 19.453264925373137
# El_Paso_2023 hasPollutant El_Paso_2023_NO2
# Travis_2021_PM2.5 hasConcentration 8.864828897338402
# Dallas_2020_CO hasConcentration 0.2811475409836065
# Alameda_2023_NO2 hasConcentration 17.00995219469796
# Allegheny_2022_NO2 hasConcentration 15.158031674208146
# El_Paso_2018 hasPollutant El_Paso_2018_NO2
# Adams_2022 hasCounty Adams
# Harris_2018_CO hasConcentration 0.4350732600732601
# York_2018 hasPollutant York_2018_NO2
# Fresno_2019 hasPollutant Fresno_2019_PM2.5
# Humboldt_2020 hasPollutant Humboldt_2020_CO
# Fresno_2022 hasPollutant Fresno_2022_CO
# Travis_2018 hasMaxAQI 150.0
# Dallas_2021 hasPollutant Dallas_2021_NO2
# Fresno_2020 hasPopulation 1009552
# Texas hasState Jefferson
# Madera_2018_CO hasConcentration 0.2481792717086835
# York_2019 hasPopulation 449341
# Allegheny_2020 hasPollutant Allegheny_2020_CO
# Fresno_2018 hasPollutant Fresno_2018_NO2
# Harrison_2022 hasPollutant Harrison_2022_PM2.5
# Alameda_2022_CO hasConcentration 0.4944598337950138
# Harrison_2018 hasPollutant Harrison_2018_PM2.5
# Los_Angeles_2020 hasPollutant Los_Angeles_2020_NO2
# Alameda_2022 hasPollutant Alameda_2022_CO
# Bexar_2022_PM2.5 hasConcentration 8.972931276297334
# Jefferson_2018 hasCounty Jefferson
# Fresno_2022 hasMaxAQI 159.0
# Los_Angeles hasRUCC 1.0
# Allegheny_2021 hasCounty Allegheny
# Travis_2023_PM2.5 hasConcentration 10.04275092936803
# Travis_2018 hasPopulation 1246693
# Philadelphia_2023 hasPollutant Philadelphia_2023_PM2.5
# York hasRUCC 2.0
# Allegheny_2020 hasPollutant Allegheny_2020_NO2
# Lackawanna_2018 hasPollutant Lackawanna_2018_CO
# Monroe_2020_CO hasConcentration 0.2764044943820224
# Butte_2020 hasPopulation 210151
# Travis_2019 hasPollutant Travis_2019_CO
# Fresno_2022 hasPopulation 1015359
# Bexar_2020 hasPollutant Bexar_2020_CO
# Imperial_2022 hasCounty Imperial
# Harrison_2018 hasPopulation 66693
# Erie_2019 hasPopulation 918813
# Monroe_2022 hasMaxAQI 126.0
# El_Paso_2018 hasPollutant El_Paso_2018_PM2.5
# Travis_2023_NO2 hasConcentration 17.71965517241379
# El_Paso_2023_CO hasConcentration 0.3986404833836857
# El_Paso_2018_PM2.5 hasConcentration 8.704336569579288
# Harrison_2022 hasMaxAQI 173.0
# California hasState Fresno
# York_2018_CO hasConcentration 0.341025641025641
# Travis_2019 hasMaxAQI 115.0
# Lackawanna_2022 hasPollutant Lackawanna_2022_CO
# Imperial_2018 hasPopulation 181062
# Los_Angeles_2021 hasPollutant Los_Angeles_2021_PM2.5
# Tarrant_2018_PM2.5 hasConcentration 8.769153225806452
# Bexar_2022 hasCounty Bexar
# Contra_Costa_2021 hasPollutant Contra_Costa_2021_NO2
# Harrison_2019 hasPollutant Harrison_2019_PM2.5
# Allegheny_2019_PM2.5 hasConcentration 10.682
# Alameda_2023 hasPopulation 1622188
# Cambria_2023 hasPollutant Cambria_2023_CO
# Alameda_2019 hasMaxAQI 150.0
# Allegheny_2023 hasPollutant Allegheny_2023_PM2.5
# Pennsylvania hasState Philadelphia
# Los_Angeles_2023 hasMaxAQI 192.0
# Kern_2023_PM2.5 hasConcentration 8.689150943396227
# Philadelphia_2020_CO hasConcentration 0.5161319890009166
# Humboldt_2022 hasCounty Humboldt
# Alameda_2019 hasPopulation 1668412
# Humboldt_2019 hasMaxAQI 65.0
# Allegheny_2019 hasCounty Allegheny
# Cambria_2019 hasMaxAQI 88.0
# Allegheny_2019 hasPollutant Allegheny_2019_CO
# York_2020 hasPopulation 456720
# Madera_2019 hasPollutant Madera_2019_PM2.5
# Erie_2019 hasMaxAQI 93.0
# Butte_2022_PM2.5 hasConcentration 6.188046387154326
# Alameda_2018_CO hasConcentration 0.6169452449567724
# Jefferson_2021 hasMaxAQI 115.0
# El_Paso_2020_NO2 hasConcentration 30.30030456852792
# Alameda_2021_NO2 hasConcentration 18.343393466601658
# Harrison_2020_NO2 hasConcentration 4.620612813370474
# Allegheny_2021_PM2.5 hasConcentration 10.324599125364433
# York_2020 hasPollutant York_2020_PM2.5
# Philadelphia_2018 hasPopulation 1586422
# Alameda_2020 hasPollutant Alameda_2020_CO
# Kern_2022_CO hasConcentration 0.356198347107438
# Philadelphia_2021_CO hasConcentration 0.5001838235294118
# El_Paso_2022 hasMaxAQI 163.0
# Jefferson_2022_PM2.5 hasConcentration 8.236007640878702
# Butte_2021_PM2.5 hasConcentration 10.351454545454546
# Los_Angeles_2021 hasPollutant Los_Angeles_2021_CO
# Madera hasRUCC 1.0
# Imperial_2019 hasPollutant Imperial_2019_CO
# Humboldt_2023 hasPollutant Humboldt_2023_NO2
# Kern_2023 hasPopulation 913820
# Monroe_2018 hasCounty Monroe
# Kern_2019 hasMaxAQI 548.0
# Adams_2020 hasCounty Adams
# Adams_2022 hasPollutant Adams_2022_NO2
# Kern_2018 hasPopulation 893618
# Madera_2020 hasMaxAQI 250.0
# Imperial_2021 hasPollutant Imperial_2021_PM2.5
# Philadelphia_2020 hasPollutant Philadelphia_2020_CO
# Contra_Costa_2023 hasMaxAQI 87.0
# Adams_2018 hasPopulation 103035
# Harrison_2021_PM2.5 hasConcentration 9.291315789473684
# Los_Angeles_2018_NO2 hasConcentration 27.091402997502083
# Travis_2018 hasCounty Travis
# Los_Angeles_2021_CO hasConcentration 0.4879032258064516
# Adams_2019 hasPopulation 102776
# Humboldt_2021 hasPollutant Humboldt_2021_NO2
# El_Paso_2019 hasPollutant El_Paso_2019_NO2
# Cambria_2021 hasMaxAQI 130.0
# Travis_2018_PM2.5 hasConcentration 8.554565456545655
# Erie_2021 hasMaxAQI 101.0
# Texas hasState Dallas
# Contra_Costa_2023_CO hasConcentration 0.3449490268767377
# Harrison_2022_NO2 hasConcentration 6.8575949367088604
# Imperial_2020 hasPollutant Imperial_2020_PM2.5
# Allegheny_2023_NO2 hasConcentration 15.873087557603686
# Tarrant_2018 hasPollutant Tarrant_2018_PM2.5
# Contra_Costa_2022 hasPollutant Contra_Costa_2022_NO2
# Lackawanna_2018 hasPollutant Lackawanna_2018_PM2.5
# Butte_2020 hasCounty Butte
# Alameda_2023_CO hasConcentration 0.5192307692307693
# Butte_2019 hasMaxAQI 173.0
# Fresno_2018 hasPollutant Fresno_2018_CO
# Los_Angeles_2019 hasPopulation 10011602
# El_Paso_2022_NO2 hasConcentration 29.809365558912383
# Adams_2020 hasPollutant Adams_2020_PM2.5
# Lackawanna_2023_CO hasConcentration 0.3378082191780822
# York_2022 hasPollutant York_2022_NO2
# Alameda_2018 hasPopulation 1666596
# Jefferson_2020_NO2 hasConcentration 9.55506268081003
# Contra_Costa_2023 hasCounty Contra_Costa
# Harris_2019 hasPollutant Harris_2019_NO2
# Madera_2019_PM2.5 hasConcentration 9.612885154061626
# Jefferson_2018_CO hasConcentration 0.1812121212121212
# Philadelphia_2020_PM2.5 hasConcentration 7.497890733056709
# Erie_2022 hasMaxAQI 150.0
# Jefferson_2019 hasPopulation 251315
# Monroe_2019_CO hasConcentration 0.304055944055944
# Tarrant_2023 hasMaxAQI 143.0
# Los_Angeles_2021_PM2.5 hasConcentration 12.454339143064631
# Butte_2019 hasCounty Butte
# Cambria_2018 hasPollutant Cambria_2018_CO
# Tarrant_2018 hasMaxAQI 150.0
# Humboldt_2019_PM2.5 hasConcentration 6.78785046728972
# Harris_2022_CO hasConcentration 0.4622868605817453
# Erie_2019 hasPollutant Erie_2019_CO
# Travis_2019_NO2 hasConcentration 16.31578947368421
# Imperial_2019 hasPollutant Imperial_2019_PM2.5
# Los_Angeles_2019 hasPollutant Los_Angeles_2019_NO2
# Harrison_2020 hasPollutant Harrison_2020_PM2.5
# Humboldt_2020 hasPollutant Humboldt_2020_PM2.5
# Travis_2023 hasPollutant Travis_2023_CO
# Tarrant_2023 hasPollutant Tarrant_2023_CO
# York_2018 hasCounty York
# El_Paso_2021_PM2.5 hasConcentration 9.335194805194806
# York_2018 hasMaxAQI 150.0
# Harris_2019_CO hasConcentration 0.4113970588235294
# Erie_2022 hasCounty Erie
# Cambria_2019 hasPopulation 130107
# Humboldt_2021 hasPollutant Humboldt_2021_CO
# Monroe_2019 hasCounty Monroe
# Madera_2020 hasCounty Madera
# El_Paso_2020 hasCounty El_Paso
# Travis_2023_CO hasConcentration 0.5994134897360704
# Monroe_2021 hasCounty Monroe
# Bexar_2021 hasPollutant Bexar_2021_CO
# El_Paso_2021 hasPopulation 867499
# Tarrant_2020 hasCounty Tarrant
# Philadelphia_2018 hasPollutant Philadelphia_2018_NO2
# El_Paso_2018 hasMaxAQI 150.0
# Lackawanna_2022 hasPollutant Lackawanna_2022_NO2
# Lackawanna_2018_NO2 hasConcentration 20.45706371191136
# Dallas_2021_CO hasConcentration 0.2863372093023256
# Travis_2019 hasPollutant Travis_2019_PM2.5
# Lackawanna_2021 hasPollutant Lackawanna_2021_CO
# Fresno_2022 hasPollutant Fresno_2022_NO2
# Madera_2019 hasCounty Madera
# Tarrant_2022 hasPopulation 2155646
# Contra_Costa_2020 hasCounty Contra_Costa
# Adams_2022 hasPollutant Adams_2022_CO
# Adams hasRUCC 3.0
# Allegheny_2022 hasMaxAQI 151.0
# Los_Angeles_2018 hasPollutant Los_Angeles_2018_NO2
# York_2018 hasPollutant York_2018_CO
# Travis_2020 hasPollutant Travis_2020_NO2
# Dallas_2019_PM2.5 hasConcentration 9.10320945945946
# Adams_2018 hasMaxAQI 150.0
# Philadelphia_2021 hasMaxAQI 152.0
# Tarrant_2022 hasCounty Tarrant
# Kern_2020 hasCounty Kern
# Harrison_2019 hasMaxAQI 90.0
# Imperial_2020_PM2.5 hasConcentration 10.892923076923076
# Imperial_2018_PM2.5 hasConcentration 12.108333333333333
# Allegheny_2020_CO hasConcentration 0.4680933852140078
# Erie_2019 hasCounty Erie
# Madera_2022 hasPopulation 160329
# Lackawanna_2020_PM2.5 hasConcentration 6.513025210084034
# Lackawanna_2018 hasPopulation 210301
# Cambria_2022 hasCounty Cambria
# El_Paso_2018 hasPopulation 835590
# Harrison_2018 hasMaxAQI 150.0
# Imperial_2022_CO hasConcentration 0.5532163742690058
# Contra_Costa hasRUCC 1.0
# Philadelphia_2020 hasCounty Philadelphia
# Travis hasRUCC 1.0
# Butte_2021 hasMaxAQI 233.0
# Kern_2020 hasPollutant Kern_2020_PM2.5
# Lackawanna_2019_CO hasConcentration 0.2751396648044693
# Tarrant_2021_NO2 hasConcentration 17.81577164973391
# Bexar_2018_CO hasConcentration 0.4498630136986301
# Kern_2022 hasPopulation 916751
# Tarrant_2021_CO hasConcentration 0.4889196675900277
# Madera_2018 hasPollutant Madera_2018_PM2.5
# Harrison hasRUCC 2.0
# Dallas_2022 hasPollutant Dallas_2022_PM2.5
# Adams_2018_CO hasConcentration 0.1318681318681318
# Jefferson_2018 hasPollutant Jefferson_2018_NO2
# Dallas_2020 hasPollutant Dallas_2020_PM2.5
# York_2021 hasCounty York
# Lackawanna_2020_CO hasConcentration 0.2819672131147541
# Tarrant_2019 hasPollutant Tarrant_2019_NO2
# York_2023 hasPollutant York_2023_NO2
# Harrison_2023_PM2.5 hasConcentration 8.713881019830028
# Bexar_2022 hasPollutant Bexar_2022_CO
# Jefferson_2020 hasMaxAQI 122.0
# Adams_2023 hasPollutant Adams_2023_NO2
# Harris_2019 hasCounty Harris
# Butte_2022 hasPopulation 207369
# Erie_2021 hasPollutant Erie_2021_CO
# Jefferson_2023 hasPollutant Jefferson_2023_PM2.5
# Harris_2021 hasPollutant Harris_2021_NO2
# Allegheny_2020 hasCounty Allegheny
# Alameda_2021 hasMaxAQI 151.0
# Tarrant_2023 hasPollutant Tarrant_2023_NO2
# Bexar_2019 hasPollutant Bexar_2019_PM2.5
# Bexar_2019_CO hasConcentration 0.4262430939226519
# Fresno_2023_CO hasConcentration 0.4499999999999999
# Dallas_2020_NO2 hasConcentration 16.212564671101255
# Jefferson_2022_NO2 hasConcentration 11.143055555555556
# Dallas_2023 hasPollutant Dallas_2023_NO2
# Allegheny_2022_PM2.5 hasConcentration 8.97345238095238
# Philadelphia_2018_PM2.5 hasConcentration 8.817489711934156
# Fresno_2020 hasPollutant Fresno_2020_NO2
# Bexar_2021_PM2.5 hasConcentration 8.936915561758548
# Bexar_2023 hasPollutant Bexar_2023_CO
# York_2019_PM2.5 hasConcentration 8.629359823399557
# Monroe_2022 hasPollutant Monroe_2022_CO
# Bexar_2018_PM2.5 hasConcentration 7.998724954462659
# Travis_2020_CO hasConcentration 0.5854794520547945
# Philadelphia_2020 hasPollutant Philadelphia_2020_PM2.5
# Cambria_2020_CO hasConcentration 0.1690807799442897
# Humboldt_2019_CO hasConcentration 0.2855153203342618
# Humboldt_2020 hasMaxAQI 109.0
# Fresno_2018 hasPollutant Fresno_2018_PM2.5
# Dallas_2020 hasPollutant Dallas_2020_NO2
# Alameda_2022 hasCounty Alameda
# Erie_2020 hasPollutant Erie_2020_PM2.5
# Allegheny hasRUCC 1.0
# Texas hasState Travis
# Madera_2022_PM2.5 hasConcentration 10.386388888888888
# El_Paso_2018 hasCounty El_Paso
# Imperial_2022 hasPopulation 178940
# Los_Angeles_2018 hasCounty Los_Angeles
# Jefferson_2018 hasPollutant Jefferson_2018_PM2.5
# Harrison_2018 hasPollutant Harrison_2018_NO2
# Adams_2020 hasPollutant Adams_2020_NO2
# Madera_2022 hasPollutant Madera_2022_NO2
# Bexar_2020_CO hasConcentration 0.4433701657458563
# Los_Angeles_2019 hasPollutant Los_Angeles_2019_PM2.5
# Humboldt_2021 hasCounty Humboldt
# Humboldt_2022_PM2.5 hasConcentration 6.757758620689655
# Harris_2020 hasPollutant Harris_2020_CO
# Adams_2020 hasPopulation 103798
# Fresno_2021 hasMaxAQI 278.0
# Jefferson_2018_NO2 hasConcentration 9.946691519105311
# El_Paso_2022 hasPollutant El_Paso_2022_NO2
# California hasState Butte
# Bexar_2018 hasPopulation 1981061
# Dallas_2021 hasPopulation 2588235
# Harris_2018_PM2.5 hasConcentration 9.143179619477587
# Alameda_2021 hasPollutant Alameda_2021_PM2.5
# Kern_2018_PM2.5 hasConcentration 11.643714011516314
# Alameda_2019_PM2.5 hasConcentration 7.329480580252691
# Erie hasRUCC 1.0
# Allegheny_2019 hasPollutant Allegheny_2019_PM2.5
# Kern_2020_PM2.5 hasConcentration 13.760240384615384
# Dallas_2023 hasPollutant Dallas_2023_PM2.5
# York_2023 hasMaxAQI 231.0
# Monroe_2021 hasMaxAQI 100.0
# Humboldt_2018 hasCounty Humboldt
# Imperial_2023 hasPopulation 179057
# Bexar_2023 hasPollutant Bexar_2023_PM2.5
# Butte_2023 hasCounty Butte
# Dallas_2019 hasMaxAQI 143.0
# Imperial_2020_NO2 hasConcentration 21.484447674418604
# Alameda_2022 hasPopulation 1628259
# Travis_2020 hasPopulation 1296613
# El_Paso_2018_CO hasConcentration 0.4421588594704684
# Travis_2021 hasPollutant Travis_2021_CO
# Humboldt hasRUCC 5.0
# Contra_Costa_2023 hasPopulation 1155025
# Los_Angeles_2022_NO2 hasConcentration 25.870868504970925
# Alameda_2020 hasPollutant Alameda_2020_PM2.5
# Allegheny_2018 hasPollutant Allegheny_2018_NO2
# Jefferson_2023 hasPopulation 251496
# York_2018_NO2 hasConcentration 16.50194552529183
# Humboldt_2018_CO hasConcentration 0.2327777777777777
# Philadelphia hasRUCC 1.0
# Imperial_2019 hasPopulation 180439
# Lackawanna_2019_PM2.5 hasConcentration 6.276456310679612
# Los_Angeles_2021_NO2 hasConcentration 25.729291674063557
# Harris_2023 hasPollutant Harris_2023_PM2.5
# Madera_2022 hasPollutant Madera_2022_PM2.5
# Imperial_2023 hasCounty Imperial
# Travis_2018 hasPollutant Travis_2018_CO
# Lackawanna_2021 hasCounty Lackawanna
# Los_Angeles_2018_CO hasConcentration 0.4997777328753283
# Butte_2018 hasCounty Butte
# Monroe_2023 hasMaxAQI 170.0
# Erie_2018 hasPollutant Erie_2018_CO
# Cambria_2020 hasPopulation 133211
# Harris_2020 hasMaxAQI 179.0
# Lackawanna_2022_NO2 hasConcentration 25.215819209039548
# Madera_2018 hasPollutant Madera_2018_CO
# Kern_2021 hasPopulation 912709
# Philadelphia_2019 hasPollutant Philadelphia_2019_NO2
# Cambria hasRUCC 3.0
# Bexar_2021 hasPollutant Bexar_2021_NO2
# Butte_2021_NO2 hasConcentration 10.412820512820511
# Lackawanna_2020 hasCounty Lackawanna
# Adams_2021_PM2.5 hasConcentration 9.156916426512968
# Contra_Costa_2021 hasPollutant Contra_Costa_2021_CO
# Harrison_2021 hasPollutant Harrison_2021_NO2
# Alameda_2023 hasPollutant Alameda_2023_NO2
# Travis_2021 hasPopulation 1308868
# Madera_2021 hasPollutant Madera_2021_NO2
# Travis_2021_CO hasConcentration 0.6019178082191781
# Travis_2023 hasPollutant Travis_2023_NO2
# Los_Angeles_2022 hasPollutant Los_Angeles_2022_CO
# Humboldt_2020_NO2 hasConcentration 5.567058823529412
# California hasState Madera
# Butte_2018_CO hasConcentration 0.4682191780821918
# Lackawanna_2023 hasMaxAQI 268.0
# Philadelphia_2023 hasPollutant Philadelphia_2023_NO2
# Imperial_2018_CO hasConcentration 0.6045584045584045
# El_Paso_2021_NO2 hasConcentration 30.564742785445414
# Adams_2023_PM2.5 hasConcentration 11.425457875457877
# Kern_2020 hasPollutant Kern_2020_CO
# Contra_Costa_2023 hasPollutant Contra_Costa_2023_PM2.5
# Los_Angeles_2019_NO2 hasConcentration 26.129435483870967
# Madera_2018 hasMaxAQI 150.0
# Butte_2018 hasPollutant Butte_2018_NO2
# Erie_2023 hasPopulation 946147
# Q2.html

# %% [markdown]
# # Correlations

# %%
pop_pol_corr = pd.read_csv(os.path.join(analysis_path, "RUCC_Population_Pollutant_Correlation.csv"), dtype={'RUCC': int, 'Year': int})
vmt_aqi_corr = pd.read_csv(os.path.join(analysis_path, "RUCC_VMT_AQI_Correlation.csv"), dtype={'RUCC': int, 'Year': int})
pop_aqi_corr = pd.read_csv(os.path.join(analysis_path, "RUCC_Population_AQI.csv"), dtype={'RUCC': int, 'Year': int})

# %%
df1 = vmt_aqi_corr[['RUCC', 'Year', 'VMT_Correlation']]
df1 = df1.fillna(0)

df2 = pop_pol_corr[['RUCC', 'Year', 'Pollutant', 'Correlation']]
df2 = df2.rename(columns={'Correlation': 'Pollutant_Correlation'})
df2 = df2.fillna(0)

df3 = pop_pol_corr[['RUCC', 'Year', 'Correlation']]
df3 = df3.rename(columns={'Correlation': 'AQI_Correlation'})
df3 = df3.fillna(0)

# %% [markdown]
# ## Correlation - VMT vs AQI (Question 3)

# %%
''' Correlation 1 - VMT vs AQI'''
from rdflib import Graph, Literal, RDF, URIRef, Namespace
from rdflib.namespace import XSD
EX = Namespace("http://example.org/ke#")
g = Graph()

for index, row in df1.iterrows():
    rucc_year = EX[f"{row['RUCC']}_{row['Year']}"]
    rucc = Literal(row['RUCC'], datatype=XSD.integer)
    year = Literal(row['Year'], datatype=XSD.integer)
    vmt_corr = Literal(row['VMT_Correlation'], datatype=XSD.float)#EX[f"VMT_Correlation#{row['VMT_Correlation']}"]
    
    g.add((rucc_year, EX.hasRUCC, rucc))
    g.add((rucc_year, EX.ofYear, year))
    g.add((rucc_year, EX.hasVMTCorrelation, vmt_corr))

# %%
for subj, pred, obj in g:
    print(subj, pred, obj)
# Out:
# http://example.org/ke#9.0_2018.0 http://example.org/ke#ofYear 2018.0
# http://example.org/ke#1.0_2018.0 http://example.org/ke#hasRUCC 1.0
# http://example.org/ke#1.0_2019.0 http://example.org/ke#hasRUCC 1.0
# http://example.org/ke#6.0_2018.0 http://example.org/ke#hasVMTCorrelation -0.2484526199789098
# http://example.org/ke#2.0_2019.0 http://example.org/ke#hasRUCC 2.0
# http://example.org/ke#5.0_2019.0 http://example.org/ke#hasVMTCorrelation 0.0
# http://example.org/ke#6.0_2019.0 http://example.org/ke#ofYear 2019.0
# http://example.org/ke#6.0_2018.0 http://example.org/ke#ofYear 2018.0
# http://example.org/ke#2.0_2020.0 http://example.org/ke#ofYear 2020.0
# http://example.org/ke#2.0_2018.0 http://example.org/ke#hasRUCC 2.0
# http://example.org/ke#3.0_2020.0 http://example.org/ke#hasRUCC 3.0
# http://example.org/ke#9.0_2018.0 http://example.org/ke#hasRUCC 9.0
# http://example.org/ke#3.0_2018.0 http://example.org/ke#ofYear 2018.0
# http://example.org/ke#7.0_2019.0 http://example.org/ke#hasRUCC 7.0
# http://example.org/ke#9.0_2019.0 http://example.org/ke#ofYear 2019.0
# http://example.org/ke#3.0_2020.0 http://example.org/ke#hasVMTCorrelation 0.4851206239795099
# http://example.org/ke#6.0_2018.0 http://example.org/ke#hasRUCC 6.0
# http://example.org/ke#5.0_2018.0 http://example.org/ke#ofYear 2018.0
# http://example.org/ke#7.0_2020.0 http://example.org/ke#ofYear 2020.0
# http://example.org/ke#3.0_2019.0 http://example.org/ke#ofYear 2019.0
# http://example.org/ke#9.0_2018.0 http://example.org/ke#hasVMTCorrelation 0.0
# http://example.org/ke#5.0_2018.0 http://example.org/ke#hasRUCC 5.0
# http://example.org/ke#4.0_2020.0 http://example.org/ke#ofYear 2020.0
# http://example.org/ke#1.0_2020.0 http://example.org/ke#hasVMTCorrelation 0.9840938115850298
# http://example.org/ke#2.0_2019.0 http://example.org/ke#ofYear 2019.0
# http://example.org/ke#9.0_2020.0 http://example.org/ke#ofYear 2020.0
# http://example.org/ke#2.0_2018.0 http://example.org/ke#ofYear 2018.0
# http://example.org/ke#1.0_2019.0 http://example.org/ke#hasVMTCorrelation 0.953222554724765
# http://example.org/ke#9.0_2019.0 http://example.org/ke#hasRUCC 9.0
# http://example.org/ke#7.0_2020.0 http://example.org/ke#hasVMTCorrelation 0.0
# http://example.org/ke#7.0_2018.0 http://example.org/ke#ofYear 2018.0
# http://example.org/ke#8.0_2018.0 http://example.org/ke#hasVMTCorrelation 0.7200030931418596
# http://example.org/ke#3.0_2019.0 http://example.org/ke#hasVMTCorrelation 0.8598203210503591
# http://example.org/ke#4.0_2019.0 http://example.org/ke#hasRUCC 4.0
# http://example.org/ke#9.0_2019.0 http://example.org/ke#hasVMTCorrelation 0.0
# http://example.org/ke#8.0_2019.0 http://example.org/ke#hasRUCC 8.0
# http://example.org/ke#5.0_2018.0 http://example.org/ke#hasVMTCorrelation 0.0
# http://example.org/ke#5.0_2019.0 http://example.org/ke#hasRUCC 5.0
# http://example.org/ke#1.0_2018.0 http://example.org/ke#ofYear 2018.0
# http://example.org/ke#5.0_2020.0 http://example.org/ke#ofYear 2020.0
# http://example.org/ke#4.0_2018.0 http://example.org/ke#ofYear 2018.0
# http://example.org/ke#1.0_2019.0 http://example.org/ke#ofYear 2019.0
# http://example.org/ke#8.0_2018.0 http://example.org/ke#hasRUCC 8.0
# http://example.org/ke#4.0_2018.0 http://example.org/ke#hasVMTCorrelation -0.4525427657343702
# http://example.org/ke#7.0_2019.0 http://example.org/ke#ofYear 2019.0
# http://example.org/ke#6.0_2020.0 http://example.org/ke#hasRUCC 6.0
# http://example.org/ke#7.0_2018.0 http://example.org/ke#hasRUCC 7.0
# http://example.org/ke#4.0_2020.0 http://example.org/ke#hasVMTCorrelation 0.8474233320136187
# http://example.org/ke#2.0_2019.0 http://example.org/ke#hasVMTCorrelation 1.0
# http://example.org/ke#5.0_2020.0 http://example.org/ke#hasVMTCorrelation 0.0
# http://example.org/ke#4.0_2018.0 http://example.org/ke#hasRUCC 4.0
# http://example.org/ke#2.0_2018.0 http://example.org/ke#hasVMTCorrelation 1.0
# http://example.org/ke#7.0_2018.0 http://example.org/ke#hasVMTCorrelation 0.0
# http://example.org/ke#3.0_2019.0 http://example.org/ke#hasRUCC 3.0
# http://example.org/ke#2.0_2020.0 http://example.org/ke#hasVMTCorrelation 0.9999999999999998
# http://example.org/ke#6.0_2019.0 http://example.org/ke#hasRUCC 6.0
# http://example.org/ke#8.0_2019.0 http://example.org/ke#hasVMTCorrelation 0.8653496783011168
# http://example.org/ke#3.0_2018.0 http://example.org/ke#hasRUCC 3.0
# http://example.org/ke#4.0_2019.0 http://example.org/ke#hasVMTCorrelation -0.8350733790997766
# http://example.org/ke#6.0_2020.0 http://example.org/ke#hasVMTCorrelation 0.0682661834648491
# http://example.org/ke#8.0_2020.0 http://example.org/ke#ofYear 2020.0
# http://example.org/ke#4.0_2020.0 http://example.org/ke#hasRUCC 4.0
# http://example.org/ke#8.0_2018.0 http://example.org/ke#ofYear 2018.0
# http://example.org/ke#7.0_2019.0 http://example.org/ke#hasVMTCorrelation 1.0
# http://example.org/ke#8.0_2020.0 http://example.org/ke#hasVMTCorrelation 0.8144029740714358
# http://example.org/ke#6.0_2019.0 http://example.org/ke#hasVMTCorrelation -0.1012235226054889
# http://example.org/ke#2.0_2020.0 http://example.org/ke#hasRUCC 2.0
# http://example.org/ke#8.0_2020.0 http://example.org/ke#hasRUCC 8.0
# http://example.org/ke#8.0_2019.0 http://example.org/ke#ofYear 2019.0
# http://example.org/ke#1.0_2018.0 http://example.org/ke#hasVMTCorrelation 0.999662997450859
# http://example.org/ke#3.0_2018.0 http://example.org/ke#hasVMTCorrelation 0.9787294868637744
# http://example.org/ke#3.0_2020.0 http://example.org/ke#ofYear 2020.0
# http://example.org/ke#7.0_2020.0 http://example.org/ke#hasRUCC 7.0
# http://example.org/ke#5.0_2019.0 http://example.org/ke#ofYear 2019.0
# http://example.org/ke#4.0_2019.0 http://example.org/ke#ofYear 2019.0
# http://example.org/ke#5.0_2020.0 http://example.org/ke#hasRUCC 5.0
# http://example.org/ke#9.0_2020.0 http://example.org/ke#hasRUCC 9.0
# http://example.org/ke#1.0_2020.0 http://example.org/ke#hasRUCC 1.0
# http://example.org/ke#9.0_2020.0 http://example.org/ke#hasVMTCorrelation 0.0
# http://example.org/ke#6.0_2020.0 http://example.org/ke#ofYear 2020.0
# http://example.org/ke#1.0_2020.0 http://example.org/ke#ofYear 2020.0

# %%
from rdflib.plugins.sparql import prepareQuery

# Define the query
query_str = """
PREFIX ex: <http://example.org/ke#>

SELECT ?rucc ?year ?vmt_corr
WHERE {
  # ?rucc_year ex:hasRUCC ?rucc ;
             ex:ofYear ?year ;
             ex:hasVMTCorrelation ?vmt_corr .
}
"""

# Prepare the query and execute it
query = prepareQuery(query_str, initNs={"ex": EX})
results = g.query(query)

# Print the results
for row in results:
    rucc = row['rucc']
    year = row['year']
    vmt_corr = row['vmt_corr']
    print(f"RUCC: {rucc}, Year: {year}, VMT Correlation: {vmt_corr}")
# Out:
# RUCC: 6.0, Year: 2018.0, VMT Correlation: -0.2484526199789098
# RUCC: 6.0, Year: 2019.0, VMT Correlation: -0.1012235226054889
# RUCC: 6.0, Year: 2020.0, VMT Correlation: 0.0682661834648491
# RUCC: 5.0, Year: 2018.0, VMT Correlation: 0.0
# RUCC: 5.0, Year: 2019.0, VMT Correlation: 0.0
# RUCC: 5.0, Year: 2020.0, VMT Correlation: 0.0
# RUCC: 3.0, Year: 2018.0, VMT Correlation: 0.9787294868637744
# RUCC: 3.0, Year: 2019.0, VMT Correlation: 0.8598203210503591
# RUCC: 3.0, Year: 2020.0, VMT Correlation: 0.4851206239795099
# RUCC: 2.0, Year: 2018.0, VMT Correlation: 1.0
# RUCC: 2.0, Year: 2019.0, VMT Correlation: 1.0
# RUCC: 2.0, Year: 2020.0, VMT Correlation: 0.9999999999999998
# RUCC: 4.0, Year: 2018.0, VMT Correlation: -0.4525427657343702
# RUCC: 4.0, Year: 2019.0, VMT Correlation: -0.8350733790997766
# RUCC: 4.0, Year: 2020.0, VMT Correlation: 0.8474233320136187
# RUCC: 1.0, Year: 2018.0, VMT Correlation: 0.999662997450859
# RUCC: 1.0, Year: 2019.0, VMT Correlation: 0.953222554724765
# RUCC: 1.0, Year: 2020.0, VMT Correlation: 0.9840938115850298
# RUCC: 9.0, Year: 2018.0, VMT Correlation: 0.0
# RUCC: 9.0, Year: 2019.0, VMT Correlation: 0.0
# RUCC: 9.0, Year: 2020.0, VMT Correlation: 0.0
# RUCC: 7.0, Year: 2018.0, VMT Correlation: 0.0
# RUCC: 7.0, Year: 2019.0, VMT Correlation: 1.0
# RUCC: 7.0, Year: 2020.0, VMT Correlation: 0.0
# RUCC: 8.0, Year: 2018.0, VMT Correlation: 0.7200030931418596
# RUCC: 8.0, Year: 2019.0, VMT Correlation: 0.8653496783011168
# RUCC: 8.0, Year: 2020.0, VMT Correlation: 0.8144029740714358

# %%
from pyvis.network import Network
net = Network(height='750px', width='100%', directed=True, neighborhood_highlight=True, filter_menu=True)

# Add nodes and edges to the network
for subject, predicate, object in g:
    subject_label = str(subject).split("#")[-1]
    predicate_label = str(predicate).split("#")[-1]
    object_label = str(object).split("#")[-1]
    
    # subject_type = str(subject).split("#")[-2]
    # object_type = str(object).split("#")[-2]
    if subject_label not in net.node_ids:
        subject_title = subject_label
        # else:
            # subject_title = subject_type + ": " + subject_label
        net.add_node(subject_label, 
                     label=subject_label, 
                     title=subject_title, 
                     labelHighlightBold=True)
        
    if object_label not in net.node_ids:
        object_title = object_label
            
        net.add_node(object_label, 
                     label=object_label, 
                     title=object_title, 
                     labelHighlightBold=True)

    edge_color = {
        'hasRUCC': 'red',
        'ofYear': 'green',
        'hasVMTCorrelation': 'purple',
    }.get(predicate_label, 'grey')
        
    net.add_edge(subject_label, 
                     object_label, 
                     title=predicate_label, 
                     label=predicate_label, 
                     color=edge_color)
    
# # Show the network
net.save_graph(os.path.join(results_path, "kg_corr_1.html"))
net.show("kg_corr_1.html", local=False, notebook=False)
# Out:
# kg_corr_1.html

# %% [markdown]
# ## Correlation - Population vs Pollutant (Question 2)

# %%
''' Correlation 2 - Population vs Pollutant'''
from rdflib import Graph, Literal, RDF, URIRef, Namespace

EX = Namespace("http://example.org/ke#")
g = Graph()

for index, row in df2.iterrows():
    rucc_pollutant_year = EX[f"{row['RUCC']}_{row['Pollutant']}_{row['Year']}"]
    rucc = Literal(row['RUCC'], datatype=XSD.integer)
    year = Literal(row['Year'], datatype=XSD.integer)
    pollutant = Literal(row['Pollutant'])
    pollutant_corr = Literal(row['Pollutant_Correlation'])#EX[f"Pollutant_Correlation#{row['Pollutant_Correlation']}"]
    
    g.add((rucc_pollutant_year, EX.hasRUCC, rucc))
    g.add((rucc_pollutant_year, EX.ofYear, year))
    g.add((rucc_pollutant_year, EX.forPollutant, pollutant))
    g.add((rucc_pollutant_year, EX.hasCorrelation, pollutant_corr))

# %%
for subj, pred, obj in g:
    print(subj, pred, obj)
# Out:
# http://example.org/ke#3_PM2.5_2023 http://example.org/ke#hasRUCC 3
# http://example.org/ke#3_PM2.5_2019 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#2_NO2_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#2_NO2_2023 http://example.org/ke#hasCorrelation 0.7167596491833258
# http://example.org/ke#5_PM2.5_2020 http://example.org/ke#hasRUCC 5
# http://example.org/ke#1_NO2_2022 http://example.org/ke#hasCorrelation 0.6236360276525605
# http://example.org/ke#3_PM2.5_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#3_PM2.5_2022 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#3_PM2.5_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#1_PM2.5_2023 http://example.org/ke#hasRUCC 1
# http://example.org/ke#2_NO2_2022 http://example.org/ke#hasCorrelation 0.7394944700457898
# http://example.org/ke#3_NO2_2023 http://example.org/ke#hasCorrelation 0.5955145012189761
# http://example.org/ke#2_NO2_2021 http://example.org/ke#hasCorrelation 0.7507719154600286
# http://example.org/ke#2_CO_2022 http://example.org/ke#forPollutant CO
# http://example.org/ke#5_NO2_2018 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#1_PM2.5_2020 http://example.org/ke#hasRUCC 1
# http://example.org/ke#5_CO_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#5_PM2.5_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#2_CO_2019 http://example.org/ke#hasCorrelation 0.728554544010963
# http://example.org/ke#1_CO_2018 http://example.org/ke#forPollutant CO
# http://example.org/ke#2_CO_2020 http://example.org/ke#hasRUCC 2
# http://example.org/ke#3_NO2_2018 http://example.org/ke#forPollutant NO2
# http://example.org/ke#2_PM2.5_2021 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#1_CO_2023 http://example.org/ke#forPollutant CO
# http://example.org/ke#1_NO2_2020 http://example.org/ke#hasCorrelation 0.562449544148006
# http://example.org/ke#3_CO_2020 http://example.org/ke#forPollutant CO
# http://example.org/ke#5_NO2_2019 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#2_NO2_2018 http://example.org/ke#forPollutant NO2
# http://example.org/ke#5_CO_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#3_NO2_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#3_NO2_2020 http://example.org/ke#hasRUCC 3
# http://example.org/ke#5_NO2_2021 http://example.org/ke#hasRUCC 5
# http://example.org/ke#3_NO2_2022 http://example.org/ke#hasRUCC 3
# http://example.org/ke#5_NO2_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#1_PM2.5_2018 http://example.org/ke#hasRUCC 1
# http://example.org/ke#2_NO2_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#2_PM2.5_2018 http://example.org/ke#hasCorrelation 0.6396979772128729
# http://example.org/ke#1_CO_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#3_PM2.5_2023 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#5_CO_2022 http://example.org/ke#forPollutant CO
# http://example.org/ke#5_CO_2020 http://example.org/ke#hasRUCC 5
# http://example.org/ke#1_PM2.5_2020 http://example.org/ke#hasCorrelation 0.1408813050555487
# http://example.org/ke#2_CO_2018 http://example.org/ke#hasCorrelation 0.3918989206843191
# http://example.org/ke#5_PM2.5_2023 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#5_CO_2019 http://example.org/ke#hasRUCC 5
# http://example.org/ke#2_CO_2019 http://example.org/ke#hasRUCC 2
# http://example.org/ke#3_NO2_2023 http://example.org/ke#forPollutant NO2
# http://example.org/ke#5_PM2.5_2019 http://example.org/ke#hasRUCC 5
# http://example.org/ke#5_NO2_2020 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#3_NO2_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#1_CO_2020 http://example.org/ke#hasRUCC 1
# http://example.org/ke#2_PM2.5_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#5_NO2_2023 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#1_PM2.5_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#5_NO2_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#3_CO_2023 http://example.org/ke#hasRUCC 3
# http://example.org/ke#1_NO2_2019 http://example.org/ke#hasRUCC 1
# http://example.org/ke#2_NO2_2018 http://example.org/ke#hasRUCC 2
# http://example.org/ke#5_CO_2023 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#3_PM2.5_2020 http://example.org/ke#hasCorrelation 0.9823255557605868
# http://example.org/ke#2_NO2_2023 http://example.org/ke#forPollutant NO2
# http://example.org/ke#2_CO_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#3_CO_2021 http://example.org/ke#hasCorrelation 0.6984375367375314
# http://example.org/ke#5_PM2.5_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#2_CO_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#2_PM2.5_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#1_PM2.5_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#1_PM2.5_2021 http://example.org/ke#hasCorrelation 0.2839207508756811
# http://example.org/ke#2_CO_2021 http://example.org/ke#hasCorrelation 0.9268809177437244
# http://example.org/ke#2_NO2_2020 http://example.org/ke#forPollutant NO2
# http://example.org/ke#3_NO2_2019 http://example.org/ke#forPollutant NO2
# http://example.org/ke#3_CO_2018 http://example.org/ke#hasRUCC 3
# http://example.org/ke#2_PM2.5_2021 http://example.org/ke#hasCorrelation 0.6813103858385335
# http://example.org/ke#3_CO_2019 http://example.org/ke#hasCorrelation 0.7654584436655373
# http://example.org/ke#1_PM2.5_2021 http://example.org/ke#hasRUCC 1
# http://example.org/ke#5_PM2.5_2023 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#3_PM2.5_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#5_CO_2018 http://example.org/ke#hasRUCC 5
# http://example.org/ke#3_PM2.5_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#5_NO2_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#3_CO_2023 http://example.org/ke#forPollutant CO
# http://example.org/ke#1_PM2.5_2022 http://example.org/ke#hasCorrelation 0.5558365074108091
# http://example.org/ke#1_NO2_2023 http://example.org/ke#forPollutant NO2
# http://example.org/ke#3_NO2_2020 http://example.org/ke#hasCorrelation 0.6259972538756795
# http://example.org/ke#1_PM2.5_2019 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#1_CO_2022 http://example.org/ke#forPollutant CO
# http://example.org/ke#3_NO2_2022 http://example.org/ke#forPollutant NO2
# http://example.org/ke#1_NO2_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#2_CO_2018 http://example.org/ke#forPollutant CO
# http://example.org/ke#3_CO_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#2_PM2.5_2018 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#1_CO_2019 http://example.org/ke#forPollutant CO
# http://example.org/ke#3_NO2_2022 http://example.org/ke#hasCorrelation 0.5530474408998353
# http://example.org/ke#5_PM2.5_2018 http://example.org/ke#hasRUCC 5
# http://example.org/ke#3_CO_2020 http://example.org/ke#hasCorrelation 0.8711997428689598
# http://example.org/ke#5_PM2.5_2021 http://example.org/ke#hasRUCC 5
# http://example.org/ke#5_NO2_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#1_CO_2019 http://example.org/ke#hasCorrelation 0.1436501616489403
# http://example.org/ke#1_PM2.5_2022 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#2_CO_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#1_PM2.5_2018 http://example.org/ke#hasCorrelation -0.0200960553239134
# http://example.org/ke#3_CO_2022 http://example.org/ke#forPollutant CO
# http://example.org/ke#2_PM2.5_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#1_CO_2023 http://example.org/ke#hasRUCC 1
# http://example.org/ke#2_NO2_2020 http://example.org/ke#hasRUCC 2
# http://example.org/ke#3_CO_2021 http://example.org/ke#hasRUCC 3
# http://example.org/ke#1_NO2_2023 http://example.org/ke#hasRUCC 1
# http://example.org/ke#3_PM2.5_2021 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#5_CO_2020 http://example.org/ke#forPollutant CO
# http://example.org/ke#1_NO2_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#2_CO_2023 http://example.org/ke#hasCorrelation 0.3402439704511067
# http://example.org/ke#3_NO2_2021 http://example.org/ke#hasCorrelation 0.5275963879319333
# http://example.org/ke#1_NO2_2019 http://example.org/ke#forPollutant NO2
# http://example.org/ke#5_NO2_2021 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#1_PM2.5_2023 http://example.org/ke#hasCorrelation 0.1717000672734639
# http://example.org/ke#2_PM2.5_2018 http://example.org/ke#hasRUCC 2
# http://example.org/ke#3_PM2.5_2021 http://example.org/ke#hasRUCC 3
# http://example.org/ke#5_PM2.5_2022 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#1_NO2_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#5_PM2.5_2021 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#5_PM2.5_2020 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#5_CO_2020 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#2_CO_2021 http://example.org/ke#hasRUCC 2
# http://example.org/ke#2_NO2_2019 http://example.org/ke#forPollutant NO2
# http://example.org/ke#3_CO_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#1_CO_2018 http://example.org/ke#hasCorrelation 0.3297585103178969
# http://example.org/ke#3_CO_2021 http://example.org/ke#forPollutant CO
# http://example.org/ke#2_NO2_2018 http://example.org/ke#hasCorrelation 0.8263575459112502
# http://example.org/ke#5_CO_2018 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#3_PM2.5_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#1_PM2.5_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#5_CO_2021 http://example.org/ke#hasRUCC 5
# http://example.org/ke#3_CO_2018 http://example.org/ke#forPollutant CO
# http://example.org/ke#2_NO2_2022 http://example.org/ke#hasRUCC 2
# http://example.org/ke#1_PM2.5_2018 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#1_NO2_2020 http://example.org/ke#hasRUCC 1
# http://example.org/ke#3_PM2.5_2022 http://example.org/ke#hasCorrelation -0.4345295741715883
# http://example.org/ke#5_PM2.5_2018 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#1_PM2.5_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#1_CO_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#5_CO_2022 http://example.org/ke#hasRUCC 5
# http://example.org/ke#1_NO2_2022 http://example.org/ke#hasRUCC 1
# http://example.org/ke#2_NO2_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#5_PM2.5_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#2_NO2_2022 http://example.org/ke#forPollutant NO2
# http://example.org/ke#1_PM2.5_2023 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#1_CO_2021 http://example.org/ke#forPollutant CO
# http://example.org/ke#2_CO_2022 http://example.org/ke#hasRUCC 2
# http://example.org/ke#5_NO2_2019 http://example.org/ke#forPollutant NO2
# http://example.org/ke#3_NO2_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#5_CO_2019 http://example.org/ke#forPollutant CO
# http://example.org/ke#2_NO2_2019 http://example.org/ke#hasRUCC 2
# http://example.org/ke#5_CO_2023 http://example.org/ke#forPollutant CO
# http://example.org/ke#2_NO2_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#5_PM2.5_2022 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#2_CO_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#1_NO2_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#2_NO2_2019 http://example.org/ke#hasCorrelation 0.7779677575821417
# http://example.org/ke#5_PM2.5_2020 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#2_CO_2023 http://example.org/ke#hasRUCC 2
# http://example.org/ke#2_PM2.5_2023 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#5_CO_2019 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#3_PM2.5_2020 http://example.org/ke#hasRUCC 3
# http://example.org/ke#3_CO_2019 http://example.org/ke#hasRUCC 3
# http://example.org/ke#3_PM2.5_2020 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#1_CO_2022 http://example.org/ke#hasCorrelation 0.1456399405946426
# http://example.org/ke#3_NO2_2021 http://example.org/ke#forPollutant NO2
# http://example.org/ke#5_CO_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#3_PM2.5_2018 http://example.org/ke#hasCorrelation 0.986616001537624
# http://example.org/ke#2_NO2_2021 http://example.org/ke#hasRUCC 2
# http://example.org/ke#1_CO_2018 http://example.org/ke#hasRUCC 1
# http://example.org/ke#3_CO_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#3_CO_2022 http://example.org/ke#hasRUCC 3
# http://example.org/ke#1_CO_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#2_CO_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#2_PM2.5_2023 http://example.org/ke#hasCorrelation 0.0142775391070872
# http://example.org/ke#5_NO2_2018 http://example.org/ke#forPollutant NO2
# http://example.org/ke#5_NO2_2022 http://example.org/ke#hasRUCC 5
# http://example.org/ke#5_PM2.5_2018 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#5_PM2.5_2021 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#2_PM2.5_2022 http://example.org/ke#hasCorrelation 0.4116436686409574
# http://example.org/ke#2_CO_2020 http://example.org/ke#forPollutant CO
# http://example.org/ke#1_PM2.5_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#3_NO2_2018 http://example.org/ke#hasRUCC 3
# http://example.org/ke#5_NO2_2018 http://example.org/ke#hasRUCC 5
# http://example.org/ke#3_CO_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#5_NO2_2019 http://example.org/ke#hasRUCC 5
# http://example.org/ke#2_PM2.5_2020 http://example.org/ke#hasCorrelation 0.7416514122027601
# http://example.org/ke#1_NO2_2020 http://example.org/ke#forPollutant NO2
# http://example.org/ke#3_CO_2018 http://example.org/ke#hasCorrelation 0.8086770012757112
# http://example.org/ke#3_NO2_2020 http://example.org/ke#forPollutant NO2
# http://example.org/ke#5_PM2.5_2019 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#1_NO2_2018 http://example.org/ke#hasRUCC 1
# http://example.org/ke#1_NO2_2022 http://example.org/ke#forPollutant NO2
# http://example.org/ke#5_CO_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#3_PM2.5_2019 http://example.org/ke#hasCorrelation -0.5233310749519668
# http://example.org/ke#1_PM2.5_2019 http://example.org/ke#hasCorrelation 0.3701078072206721
# http://example.org/ke#2_NO2_2023 http://example.org/ke#hasRUCC 2
# http://example.org/ke#3_NO2_2023 http://example.org/ke#hasRUCC 3
# http://example.org/ke#5_NO2_2023 http://example.org/ke#forPollutant NO2
# http://example.org/ke#3_CO_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#5_NO2_2022 http://example.org/ke#forPollutant NO2
# http://example.org/ke#3_NO2_2019 http://example.org/ke#hasRUCC 3
# http://example.org/ke#5_NO2_2020 http://example.org/ke#forPollutant NO2
# http://example.org/ke#3_CO_2023 http://example.org/ke#hasCorrelation 0.5830462452330013
# http://example.org/ke#5_PM2.5_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#5_CO_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#1_CO_2022 http://example.org/ke#hasRUCC 1
# http://example.org/ke#1_PM2.5_2022 http://example.org/ke#hasRUCC 1
# http://example.org/ke#2_NO2_2021 http://example.org/ke#forPollutant NO2
# http://example.org/ke#1_PM2.5_2021 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#1_NO2_2021 http://example.org/ke#hasCorrelation 0.6182243254885154
# http://example.org/ke#3_PM2.5_2023 http://example.org/ke#hasCorrelation -0.9508334080900028
# http://example.org/ke#2_PM2.5_2019 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#2_PM2.5_2021 http://example.org/ke#hasRUCC 2
# http://example.org/ke#1_CO_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#2_CO_2018 http://example.org/ke#hasRUCC 2
# http://example.org/ke#2_PM2.5_2023 http://example.org/ke#hasRUCC 2
# http://example.org/ke#1_CO_2020 http://example.org/ke#forPollutant CO
# http://example.org/ke#2_CO_2020 http://example.org/ke#hasCorrelation 0.9305907889587688
# http://example.org/ke#5_CO_2018 http://example.org/ke#forPollutant CO
# http://example.org/ke#1_NO2_2018 http://example.org/ke#hasCorrelation 0.6622303286995342
# http://example.org/ke#3_CO_2019 http://example.org/ke#forPollutant CO
# http://example.org/ke#2_PM2.5_2020 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#3_NO2_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#5_CO_2022 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#2_NO2_2020 http://example.org/ke#hasCorrelation 0.7511202886052164
# http://example.org/ke#2_CO_2022 http://example.org/ke#hasCorrelation -0.8482479724000876
# http://example.org/ke#5_PM2.5_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#1_NO2_2021 http://example.org/ke#forPollutant NO2
# http://example.org/ke#5_NO2_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#5_PM2.5_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#5_CO_2023 http://example.org/ke#hasRUCC 5
# http://example.org/ke#2_CO_2019 http://example.org/ke#forPollutant CO
# http://example.org/ke#5_CO_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#5_NO2_2021 http://example.org/ke#forPollutant NO2
# http://example.org/ke#5_NO2_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#2_CO_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#2_PM2.5_2019 http://example.org/ke#hasCorrelation 0.4692384977935689
# http://example.org/ke#5_CO_2021 http://example.org/ke#forPollutant CO
# http://example.org/ke#1_PM2.5_2019 http://example.org/ke#hasRUCC 1
# http://example.org/ke#2_NO2_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#1_PM2.5_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#2_CO_2021 http://example.org/ke#forPollutant CO
# http://example.org/ke#3_CO_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#3_NO2_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#5_NO2_2020 http://example.org/ke#hasRUCC 5
# http://example.org/ke#2_PM2.5_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#3_PM2.5_2018 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#2_PM2.5_2022 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#3_NO2_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#3_PM2.5_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#1_CO_2021 http://example.org/ke#ofYear 2021
# http://example.org/ke#1_NO2_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#1_NO2_2018 http://example.org/ke#forPollutant NO2
# http://example.org/ke#3_CO_2020 http://example.org/ke#hasRUCC 3
# http://example.org/ke#5_CO_2021 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#5_NO2_2023 http://example.org/ke#hasRUCC 5
# http://example.org/ke#3_PM2.5_2018 http://example.org/ke#hasRUCC 3
# http://example.org/ke#3_PM2.5_2019 http://example.org/ke#hasRUCC 3
# http://example.org/ke#3_NO2_2019 http://example.org/ke#hasCorrelation 0.6633151602373258
# http://example.org/ke#3_NO2_2021 http://example.org/ke#hasRUCC 3
# http://example.org/ke#1_PM2.5_2020 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#2_PM2.5_2022 http://example.org/ke#ofYear 2022
# http://example.org/ke#3_PM2.5_2022 http://example.org/ke#hasRUCC 3
# http://example.org/ke#5_PM2.5_2019 http://example.org/ke#forPollutant PM2.5
# http://example.org/ke#1_CO_2021 http://example.org/ke#hasCorrelation 0.1090232686640028
# http://example.org/ke#1_CO_2023 http://example.org/ke#hasCorrelation 0.0016850807315639
# http://example.org/ke#2_PM2.5_2019 http://example.org/ke#ofYear 2019
# http://example.org/ke#5_NO2_2022 http://example.org/ke#hasCorrelation 0.0
# http://example.org/ke#1_NO2_2020 http://example.org/ke#ofYear 2020
# http://example.org/ke#2_PM2.5_2022 http://example.org/ke#hasRUCC 2
# http://example.org/ke#1_NO2_2023 http://example.org/ke#hasCorrelation 0.5272055249260106
# http://example.org/ke#1_CO_2021 http://example.org/ke#hasRUCC 1
# http://example.org/ke#1_CO_2020 http://example.org/ke#hasCorrelation 0.048707314854287
# http://example.org/ke#2_NO2_2023 http://example.org/ke#ofYear 2023
# http://example.org/ke#3_PM2.5_2021 http://example.org/ke#hasCorrelation 0.4897485424289174
# http://example.org/ke#1_NO2_2019 http://example.org/ke#hasCorrelation 0.6387733574895565
# http://example.org/ke#2_PM2.5_2019 http://example.org/ke#hasRUCC 2
# http://example.org/ke#2_CO_2023 http://example.org/ke#forPollutant CO
# http://example.org/ke#5_PM2.5_2023 http://example.org/ke#hasRUCC 5
# http://example.org/ke#3_NO2_2018 http://example.org/ke#hasCorrelation 0.6620087902054008
# http://example.org/ke#1_NO2_2021 http://example.org/ke#hasRUCC 1
# http://example.org/ke#1_CO_2019 http://example.org/ke#hasRUCC 1
# http://example.org/ke#1_CO_2018 http://example.org/ke#ofYear 2018
# http://example.org/ke#2_PM2.5_2020 http://example.org/ke#hasRUCC 2
# http://example.org/ke#5_PM2.5_2022 http://example.org/ke#hasRUCC 5
# http://example.org/ke#3_CO_2022 http://example.org/ke#hasCorrelation 0.5065131320203168

# %%
query = """
    PREFIX ex: <http://example.org/ke#>
    SELECT ?rucc ?pollutant ?pollutant_corr
    WHERE {
        # ?rucc_pollutant_year ex:hasRUCC ?rucc ;
                              ex:forPollutant ?pollutant ;
                              ex:hasCorrelation ?pollutant_corr .
                              
    }
"""
# Execute the query
results = g.query(query)

# Print the results
for row in results:
    print(f"RUCC: {row['rucc']}, Pollutant: {row['pollutant']}, Correlation: {row['pollutant_corr']}")
# Out:
# RUCC: 1, Pollutant: NO2, Correlation: 0.6622303286995342
# RUCC: 1, Pollutant: NO2, Correlation: 0.6387733574895565
# RUCC: 1, Pollutant: NO2, Correlation: 0.562449544148006
# RUCC: 1, Pollutant: NO2, Correlation: 0.6182243254885154
# RUCC: 1, Pollutant: NO2, Correlation: 0.6236360276525605
# RUCC: 1, Pollutant: NO2, Correlation: 0.5272055249260106
# RUCC: 2, Pollutant: NO2, Correlation: 0.8263575459112502
# RUCC: 2, Pollutant: NO2, Correlation: 0.7779677575821417
# RUCC: 2, Pollutant: NO2, Correlation: 0.7511202886052164
# RUCC: 2, Pollutant: NO2, Correlation: 0.7507719154600286
# RUCC: 2, Pollutant: NO2, Correlation: 0.7394944700457898
# RUCC: 2, Pollutant: NO2, Correlation: 0.7167596491833258
# RUCC: 3, Pollutant: NO2, Correlation: 0.6620087902054008
# RUCC: 3, Pollutant: NO2, Correlation: 0.6633151602373258
# RUCC: 3, Pollutant: NO2, Correlation: 0.6259972538756795
# RUCC: 3, Pollutant: NO2, Correlation: 0.5275963879319333
# RUCC: 3, Pollutant: NO2, Correlation: 0.5530474408998353
# RUCC: 3, Pollutant: NO2, Correlation: 0.5955145012189761
# RUCC: 5, Pollutant: NO2, Correlation: 0.0
# RUCC: 5, Pollutant: NO2, Correlation: 0.0
# RUCC: 5, Pollutant: NO2, Correlation: 0.0
# RUCC: 5, Pollutant: NO2, Correlation: 0.0
# RUCC: 5, Pollutant: NO2, Correlation: 0.0
# RUCC: 5, Pollutant: NO2, Correlation: 0.0
# RUCC: 1, Pollutant: CO, Correlation: 0.3297585103178969
# RUCC: 1, Pollutant: CO, Correlation: 0.1436501616489403
# RUCC: 1, Pollutant: CO, Correlation: 0.048707314854287
# RUCC: 1, Pollutant: CO, Correlation: 0.1090232686640028
# RUCC: 1, Pollutant: CO, Correlation: 0.1456399405946426
# RUCC: 1, Pollutant: CO, Correlation: 0.0016850807315639
# RUCC: 2, Pollutant: CO, Correlation: 0.3918989206843191
# RUCC: 2, Pollutant: CO, Correlation: 0.728554544010963
# RUCC: 2, Pollutant: CO, Correlation: 0.9305907889587688
# RUCC: 2, Pollutant: CO, Correlation: 0.9268809177437244
# RUCC: 2, Pollutant: CO, Correlation: -0.8482479724000876
# RUCC: 2, Pollutant: CO, Correlation: 0.3402439704511067
# RUCC: 3, Pollutant: CO, Correlation: 0.8086770012757112
# RUCC: 3, Pollutant: CO, Correlation: 0.7654584436655373
# RUCC: 3, Pollutant: CO, Correlation: 0.8711997428689598
# RUCC: 3, Pollutant: CO, Correlation: 0.6984375367375314
# RUCC: 3, Pollutant: CO, Correlation: 0.5065131320203168
# RUCC: 3, Pollutant: CO, Correlation: 0.5830462452330013
# RUCC: 5, Pollutant: CO, Correlation: 0.0
# RUCC: 5, Pollutant: CO, Correlation: 0.0
# RUCC: 5, Pollutant: CO, Correlation: 0.0
# RUCC: 5, Pollutant: CO, Correlation: 0.0
# RUCC: 5, Pollutant: CO, Correlation: 0.0
# RUCC: 5, Pollutant: CO, Correlation: 0.0
# RUCC: 1, Pollutant: PM2.5, Correlation: -0.0200960553239134
# RUCC: 1, Pollutant: PM2.5, Correlation: 0.3701078072206721
# RUCC: 1, Pollutant: PM2.5, Correlation: 0.1408813050555487
# RUCC: 1, Pollutant: PM2.5, Correlation: 0.2839207508756811
# RUCC: 1, Pollutant: PM2.5, Correlation: 0.5558365074108091
# RUCC: 1, Pollutant: PM2.5, Correlation: 0.1717000672734639
# RUCC: 2, Pollutant: PM2.5, Correlation: 0.6396979772128729
# RUCC: 2, Pollutant: PM2.5, Correlation: 0.4692384977935689
# RUCC: 2, Pollutant: PM2.5, Correlation: 0.7416514122027601
# RUCC: 2, Pollutant: PM2.5, Correlation: 0.6813103858385335
# RUCC: 2, Pollutant: PM2.5, Correlation: 0.4116436686409574
# RUCC: 2, Pollutant: PM2.5, Correlation: 0.0142775391070872
# RUCC: 3, Pollutant: PM2.5, Correlation: 0.986616001537624
# RUCC: 3, Pollutant: PM2.5, Correlation: -0.5233310749519668
# RUCC: 3, Pollutant: PM2.5, Correlation: 0.9823255557605868
# RUCC: 3, Pollutant: PM2.5, Correlation: 0.4897485424289174
# RUCC: 3, Pollutant: PM2.5, Correlation: -0.4345295741715883
# RUCC: 3, Pollutant: PM2.5, Correlation: -0.9508334080900028
# RUCC: 5, Pollutant: PM2.5, Correlation: 0.0
# RUCC: 5, Pollutant: PM2.5, Correlation: 0.0
# RUCC: 5, Pollutant: PM2.5, Correlation: 0.0
# RUCC: 5, Pollutant: PM2.5, Correlation: 0.0
# RUCC: 5, Pollutant: PM2.5, Correlation: 0.0
# RUCC: 5, Pollutant: PM2.5, Correlation: 0.0

# %%
from pyvis.network import Network
net = Network(height='750px', width='100%', directed=True, filter_menu=True, neighborhood_highlight=True)

# Add nodes and edges to the network
for subject, predicate, object in g:
    subject_label = str(subject).split("#")[-1]
    predicate_label = str(predicate).split("#")[-1]
    object_label = str(object).split("#")[-1]
    
    # subject_type = str(subject).split("#")[-2]
    # object_type = str(object).split("#")[-2]
    if subject_label not in net.node_ids:
        # if "ke" in subject_type:
        subject_title = subject_label
        # else:
            # subject_title = subject_type + ": " + subject_label
        net.add_node(subject_label, 
                     label=subject_label, 
                     title=subject_title, 
                     labelHighlightBold=True)
        
    if object_label not in net.node_ids:
        # if "ke" in object_type:
        object_title = object_label
        # else:
            # object_title = object_type + ": " + object_label
            
        net.add_node(object_label, 
                     label=object_label, 
                     title=object_title, 
                     labelHighlightBold=True)

    edge_color = {
        'hasRUCC': 'red',
        'ofYear': 'green',
        'belongsTo': 'black',
        'forPollutant': 'pink',
        'hasPollutantCorrelation': 'purple',
        
    }.get(predicate_label, 'grey')
        
    net.add_edge(subject_label, 
                     object_label, 
                     title=predicate_label, 
                     label=predicate_label, 
                     color=edge_color)
    
# # Show the network
net.save_graph(os.path.join(results_path, "kg_corr_2.html"))
net.show("kg_corr_2.html", local=False, notebook=False)
# Out:
# kg_corr_2.html

# %% [markdown]
# ## Correlation - Population vs AQI (Question 1)

# %%
df3
# Out:
#     RUCC  Year  AQI_Correlation
# 0      1  2018         0.662230
# 1      1  2019         0.638773
# 2      1  2020         0.562450
# 3      1  2021         0.618224
# 4      1  2022         0.623636
# ..   ...   ...              ...
# 67     5  2019         0.000000
# 68     5  2020         0.000000
# 69     5  2021         0.000000
# 70     5  2022         0.000000
# 71     5  2023         0.000000
#
# [72 rows x 3 columns]

# %%
''' Correlation 3 - Population vs AQI'''
from rdflib import Graph, Literal, RDF, URIRef, Namespace

EX = Namespace("http://example.org/ke#")
g = Graph()

for index, row in df3.iterrows():
    rucc_year = EX[f"{row['RUCC']}_{row['Year']}"]
    rucc = Literal(row['RUCC'], datatype=XSD.integer)
    year = Literal(row['Year'], datatype=XSD.integer)
    aqi_corr = Literal(row['AQI_Correlation'])
    
    g.add((rucc_year, EX.hasRUCC, rucc))
    g.add((rucc_year, EX.ofYear, year))
    g.add((rucc_year, EX.hasCorrelation, aqi_corr))

# %%
query = """
    PREFIX ex: <http://example.org/ke#>
    SELECT ?rucc ?year ?aqi_corr
    WHERE {
        # ?rucc_year ex:hasRUCC ?rucc ;
                ex:ofYear ?year ;
              ex:hasCorrelation ?aqi_corr .                
    }
"""
# Execute the query
results = g.query(query)

# Print the results
for row in results:
    print(f"RUCC: {row['rucc']}, Pollutant: {row['year']}, Correlation: {row['aqi_corr']}")
# Out:
# RUCC: 1.0, Pollutant: 2018.0, Correlation: 0.6622303286995342
# RUCC: 1.0, Pollutant: 2019.0, Correlation: 0.6387733574895565
# RUCC: 1.0, Pollutant: 2020.0, Correlation: 0.562449544148006
# RUCC: 1.0, Pollutant: 2021.0, Correlation: 0.6182243254885154
# RUCC: 1.0, Pollutant: 2022.0, Correlation: 0.6236360276525605
# RUCC: 1.0, Pollutant: 2023.0, Correlation: 0.5272055249260106
# RUCC: 2.0, Pollutant: 2018.0, Correlation: 0.8263575459112502
# RUCC: 2.0, Pollutant: 2019.0, Correlation: 0.7779677575821417
# RUCC: 2.0, Pollutant: 2020.0, Correlation: 0.7511202886052164
# RUCC: 2.0, Pollutant: 2021.0, Correlation: 0.7507719154600286
# RUCC: 2.0, Pollutant: 2022.0, Correlation: 0.7394944700457898
# RUCC: 2.0, Pollutant: 2023.0, Correlation: 0.7167596491833258
# RUCC: 3.0, Pollutant: 2018.0, Correlation: 0.6620087902054008
# RUCC: 3.0, Pollutant: 2019.0, Correlation: 0.6633151602373258
# RUCC: 3.0, Pollutant: 2020.0, Correlation: 0.6259972538756795
# RUCC: 3.0, Pollutant: 2021.0, Correlation: 0.5275963879319333
# RUCC: 3.0, Pollutant: 2022.0, Correlation: 0.5530474408998353
# RUCC: 3.0, Pollutant: 2023.0, Correlation: 0.5955145012189761
# RUCC: 5.0, Pollutant: 2018.0, Correlation: 0.0
# RUCC: 5.0, Pollutant: 2019.0, Correlation: 0.0
# RUCC: 5.0, Pollutant: 2020.0, Correlation: 0.0
# RUCC: 5.0, Pollutant: 2021.0, Correlation: 0.0
# RUCC: 5.0, Pollutant: 2022.0, Correlation: 0.0
# RUCC: 5.0, Pollutant: 2023.0, Correlation: 0.0
# RUCC: 1.0, Pollutant: 2018.0, Correlation: 0.3297585103178969
# RUCC: 1.0, Pollutant: 2019.0, Correlation: 0.1436501616489403
# RUCC: 1.0, Pollutant: 2020.0, Correlation: 0.048707314854287
# RUCC: 1.0, Pollutant: 2021.0, Correlation: 0.1090232686640028
# RUCC: 1.0, Pollutant: 2022.0, Correlation: 0.1456399405946426
# RUCC: 1.0, Pollutant: 2023.0, Correlation: 0.0016850807315639
# RUCC: 2.0, Pollutant: 2018.0, Correlation: 0.3918989206843191
# RUCC: 2.0, Pollutant: 2019.0, Correlation: 0.728554544010963
# RUCC: 2.0, Pollutant: 2020.0, Correlation: 0.9305907889587688
# RUCC: 2.0, Pollutant: 2021.0, Correlation: 0.9268809177437244
# RUCC: 2.0, Pollutant: 2022.0, Correlation: -0.8482479724000876
# RUCC: 2.0, Pollutant: 2023.0, Correlation: 0.3402439704511067
# RUCC: 3.0, Pollutant: 2018.0, Correlation: 0.8086770012757112
# RUCC: 3.0, Pollutant: 2019.0, Correlation: 0.7654584436655373
# RUCC: 3.0, Pollutant: 2020.0, Correlation: 0.8711997428689598
# RUCC: 3.0, Pollutant: 2021.0, Correlation: 0.6984375367375314
# RUCC: 3.0, Pollutant: 2022.0, Correlation: 0.5065131320203168
# RUCC: 3.0, Pollutant: 2023.0, Correlation: 0.5830462452330013
# RUCC: 1.0, Pollutant: 2018.0, Correlation: -0.0200960553239134
# RUCC: 1.0, Pollutant: 2019.0, Correlation: 0.3701078072206721
# RUCC: 1.0, Pollutant: 2020.0, Correlation: 0.1408813050555487
# RUCC: 1.0, Pollutant: 2021.0, Correlation: 0.2839207508756811
# RUCC: 1.0, Pollutant: 2022.0, Correlation: 0.5558365074108091
# RUCC: 1.0, Pollutant: 2023.0, Correlation: 0.1717000672734639
# RUCC: 2.0, Pollutant: 2018.0, Correlation: 0.6396979772128729
# RUCC: 2.0, Pollutant: 2019.0, Correlation: 0.4692384977935689
# RUCC: 2.0, Pollutant: 2020.0, Correlation: 0.7416514122027601
# RUCC: 2.0, Pollutant: 2021.0, Correlation: 0.6813103858385335
# RUCC: 2.0, Pollutant: 2022.0, Correlation: 0.4116436686409574
# RUCC: 2.0, Pollutant: 2023.0, Correlation: 0.0142775391070872
# RUCC: 3.0, Pollutant: 2018.0, Correlation: 0.986616001537624
# RUCC: 3.0, Pollutant: 2019.0, Correlation: -0.5233310749519668
# RUCC: 3.0, Pollutant: 2020.0, Correlation: 0.9823255557605868
# RUCC: 3.0, Pollutant: 2021.0, Correlation: 0.4897485424289174
# RUCC: 3.0, Pollutant: 2022.0, Correlation: -0.4345295741715883
# RUCC: 3.0, Pollutant: 2023.0, Correlation: -0.9508334080900028

# %%
from pyvis.network import Network
net = Network(height='750px', width='100%', directed=True, neighborhood_highlight=True, filter_menu=True)

# Add nodes and edges to the network
for subject, predicate, object in g:
    subject_label = str(subject).split("#")[-1]
    predicate_label = str(predicate).split("#")[-1]
    object_label = str(object).split("#")[-1]
    
    # subject_type = str(subject).split("#")[-2]
    # object_type = str(object).split("#")[-2]
    if subject_label not in net.node_ids:
        subject_title = subject_label
        # else:
            # subject_title = subject_type + ": " + subject_label
        net.add_node(subject_label, 
                     label=subject_label, 
                     title=subject_title, 
                     labelHighlightBold=True)
        
    if object_label not in net.node_ids:
        object_title = object_label
            
        net.add_node(object_label, 
                     label=object_label, 
                     title=object_title, 
                     labelHighlightBold=True)

    edge_color = {
        'hasRUCC': 'red',
        'ofYear': 'green',
        'hasCorrelation': 'purple',
    }.get(predicate_label, 'grey')
        
    net.add_edge(subject_label, 
                     object_label, 
                     title=predicate_label, 
                     label=predicate_label, 
                     color=edge_color)
    
# # Show the network
net.save_graph(os.path.join(results_path, "kg_corr_3.html"))
net.show("kg_corr_3.html", local=False, notebook=False)
# Out:
# kg_corr_3.html
